# %%
import g20_functions as g20


values = g20.balanceData(g20.loadToxic(), dataset = 'Toxic')
# Out:
# Minority class: 741
# Majority class: 8251
# Proportion: 0.09 : 1

# %%
import g20_KNN
import numpy as np
import pandas as pd
for k,v in values.items():
    X,y,labels = g20.xySplit(v,target=1024)
    g20_KNN.holdoutKNN(X,y,labels,"Toxic_"+k)

# %%
from g20_Naive_Bayes import holdoutNaiveBayes
import numpy as np
import pandas as pd
for k,v in values.items():
    X,y,labels = g20.xySplit(v,target=1024)
    holdoutNaiveBayes(X,y,labels,"Toxic_"+k)
# Out:
# -> Holdout for Toxic_Original:
# Holdout score forToxic_Original: [0.75 0.85 0.78]
# -> Holdout for Toxic_UnderSample:
# Holdout score forToxic_UnderSample: [0.73 0.7  0.68]
# -> Holdout for Toxic_OverSample:
# Holdout score forToxic_OverSample: [0.76 0.75 0.72]
# -> Holdout for Toxic_SMOTE:
# Holdout score forToxic_SMOTE: [0.76 0.84 0.78]
