# %%
import numpy as np
import pandas as pd
import g20_functions as g20
import g20_Pattern_Mining as g20PM
import ds_functions as ds

# %%
data = g20.dummify(g20.loadHeart())
values = {'Dummified by width': data[0]}

np.shape(data[0])
# Out:
# (299, 165)

# %%
patterns = {}
MIN_SUP: float = 0.005
var_min_sup =[0.4, 0.3, 0.2, 0.18, 0.16, 0.14, 0.12, 0.1, 0.08, 0.06, 0.04, 0.02]
for name, data in values.items():
    print("-------------{}-------------".format(name))
    patterns[name] = g20PM.get_patterns(data,MIN_SUP)
    g20PM.plot_patterns(patterns[name],var_min_sup)
# Out:
# -------------Dummified by width-------------
# 82 itemset(s) from tree conditioned on items ()
# 0 itemset(s) from tree conditioned on items (smoking_0)
# 1 itemset(s) from tree conditioned on items (sex_1)
# 3 itemset(s) from tree conditioned on items (diabetes_0)
# 0 itemset(s) from tree conditioned on items (diabetes_0, sex_1)
# 2 itemset(s) from tree conditioned on items (diabetes_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (diabetes_0, smoking_0, sex_1)
# 0 itemset(s) from tree conditioned on items (diabetes_0, smoking_0, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (diabetes_0, high_blood_pressure_0)
# 4 itemset(s) from tree conditioned on items (anaemia_0)
# 0 itemset(s) from tree conditioned on items (anaemia_0, sex_1)
# 2 itemset(s) from tree conditioned on items (anaemia_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (anaemia_0, smoking_0, sex_1)
# 0 itemset(s) from tree conditioned on items (anaemia_0, smoking_0, high_blood_pressure_0)
# 3 itemset(s) from tree conditioned on items (anaemia_0, diabetes_0)
# 0 itemset(s) from tree conditioned on items (anaemia_0, diabetes_0, sex_1)
# 2 itemset(s) from tree conditioned on items (anaemia_0, diabetes_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (anaemia_0, diabetes_0, smoking_0, sex_1)
# 0 itemset(s) from tree conditioned on items (anaemia_0, diabetes_0, smoking_0, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (anaemia_0, diabetes_0, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (anaemia_0, high_blood_pressure_0)
# 10 itemset(s) from tree conditioned on items (high_blood_pressure_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_0)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, sex_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, sex_1, diabetes_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, sex_1, smoking_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, anaemia_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, anaemia_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, anaemia_0, sex_1)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, anaemia_0, diabetes_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, anaemia_0, diabetes_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, anaemia_0, diabetes_0, sex_1)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, anaemia_1)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, anaemia_1, diabetes_0)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, anaemia_1, sex_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, anaemia_1, sex_1, diabetes_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, anaemia_1, sex_1, smoking_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, anaemia_1, smoking_0)
# 5 itemset(s) from tree conditioned on items (high_blood_pressure_1, creatinine_phosphokinase_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, creatinine_phosphokinase_0, anaemia_1)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, creatinine_phosphokinase_0, sex_1)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, creatinine_phosphokinase_0, sex_1, anaemia_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, creatinine_phosphokinase_0, sex_1, smoking_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, creatinine_phosphokinase_0, diabetes_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, creatinine_phosphokinase_0, diabetes_0, sex_1)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, creatinine_phosphokinase_0, diabetes_0, anaemia_1)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, creatinine_phosphokinase_0, diabetes_0, anaemia_1, sex_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, creatinine_phosphokinase_0, diabetes_0, anaemia_1, smoking_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, creatinine_phosphokinase_0, diabetes_0, smoking_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, creatinine_phosphokinase_0, smoking_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, creatinine_phosphokinase_0, anaemia_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, creatinine_phosphokinase_0, anaemia_0, sex_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, creatinine_phosphokinase_0, anaemia_0, smoking_0)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, creatinine_phosphokinase_0, anaemia_0, diabetes_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, creatinine_phosphokinase_0, anaemia_0, diabetes_0, sex_1)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, creatinine_phosphokinase_0, anaemia_0, diabetes_0, smoking_0)
# 9 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, sex_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, sex_1, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, sex_1, anaemia_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, diabetes_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, diabetes_0, sex_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, diabetes_0, smoking_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, diabetes_0, anaemia_0)
# 6 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, sex_1)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, diabetes_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, diabetes_0, sex_1)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, diabetes_0, smoking_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, smoking_0)
# 4 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, sex_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, sex_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, sex_0, diabetes_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, sex_0, diabetes_1)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, sex_0, anaemia_0)
# 4 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, anaemia_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, anaemia_0, smoking_0)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, anaemia_0, sex_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, anaemia_0, sex_1, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, anaemia_0, sex_1, diabetes_1)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, anaemia_0, diabetes_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, anaemia_0, diabetes_1)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, diabetes_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, diabetes_1, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, creatinine_phosphokinase_0, diabetes_1, sex_1)
# 6 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_1)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_1, diabetes_0)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_1, creatinine_phosphokinase_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_1, creatinine_phosphokinase_0, diabetes_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_1, creatinine_phosphokinase_0, smoking_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_1, sex_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_1, sex_1, diabetes_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_1, sex_1, creatinine_phosphokinase_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_1, sex_1, smoking_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_1, smoking_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_1, sex_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_1, sex_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_1, sex_0, creatinine_phosphokinase_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_1, sex_0, diabetes_0)
# 4 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_1, diabetes_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_1, diabetes_1, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_1, diabetes_1, sex_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_1, diabetes_1, sex_1)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_1, diabetes_1, creatinine_phosphokinase_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, smoking_0)
# 8 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, smoking_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, diabetes_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, sex_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, sex_1, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, sex_1, diabetes_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, sex_1, anaemia_0)
# 5 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, creatinine_phosphokinase_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, creatinine_phosphokinase_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, creatinine_phosphokinase_0, sex_1)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, creatinine_phosphokinase_0, diabetes_0)
# 7 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, creatinine_phosphokinase_0, anaemia_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, creatinine_phosphokinase_0, sex_0)
# 6 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, anaemia_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, anaemia_1, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, anaemia_1, creatinine_phosphokinase_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, anaemia_1, diabetes_0)
# 7 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, anaemia_1, sex_1)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, anaemia_1, sex_0)
# 7 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, anaemia_1, diabetes_1)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, anaemia_0)
# 5 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, diabetes_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, diabetes_1, smoking_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, diabetes_1, anaemia_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, diabetes_1, sex_1)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, diabetes_1, sex_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, diabetes_1, creatinine_phosphokinase_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, sex_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, sex_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, sex_0, anaemia_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, serum_sodium_6, sex_0, diabetes_0)
# 4 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, sex_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, sex_0, smoking_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, sex_0, diabetes_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, sex_0, diabetes_1)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, sex_0, anaemia_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, anaemia_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, diabetes_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, diabetes_1, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, diabetes_1, anaemia_0)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, diabetes_1, sex_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, diabetes_1, sex_1, anaemia_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, ejection_fraction_3, diabetes_1, sex_1, smoking_0)
# 8 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, smoking_0)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, sex_1)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, sex_1, smoking_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, sex_1, anaemia_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, diabetes_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, diabetes_0, sex_1)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, diabetes_0, smoking_0)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, diabetes_0, anaemia_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, diabetes_0, anaemia_0, sex_1)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, diabetes_0, anaemia_0, smoking_0)
# 5 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, creatinine_phosphokinase_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, creatinine_phosphokinase_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, creatinine_phosphokinase_0, sex_1)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, creatinine_phosphokinase_0, diabetes_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, creatinine_phosphokinase_0, diabetes_0, sex_1)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, creatinine_phosphokinase_0, diabetes_0, smoking_0)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, creatinine_phosphokinase_0, diabetes_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, creatinine_phosphokinase_0, diabetes_1, smoking_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, creatinine_phosphokinase_0, diabetes_1, sex_1)
# 4 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, creatinine_phosphokinase_0, anaemia_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, creatinine_phosphokinase_0, anaemia_0, sex_1)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, creatinine_phosphokinase_0, anaemia_0, diabetes_1)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, creatinine_phosphokinase_0, anaemia_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, creatinine_phosphokinase_0, anaemia_0, diabetes_0)
# 6 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, anaemia_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, anaemia_1, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, anaemia_1, creatinine_phosphokinase_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, anaemia_1, diabetes_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, anaemia_1, diabetes_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, anaemia_1, diabetes_0, creatinine_phosphokinase_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, anaemia_1, diabetes_0, sex_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, anaemia_1, sex_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, anaemia_1, sex_1, diabetes_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, anaemia_1, sex_1, smoking_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, anaemia_1, sex_1, creatinine_phosphokinase_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, anaemia_1, sex_0)
# 7 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, anaemia_1, diabetes_1)
# 5 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, sex_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, sex_0, smoking_0)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, sex_0, creatinine_phosphokinase_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, sex_0, creatinine_phosphokinase_0, smoking_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, sex_0, creatinine_phosphokinase_0, diabetes_1)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, sex_0, diabetes_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, sex_0, diabetes_1)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, sex_0, anaemia_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, sex_0, anaemia_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, sex_0, anaemia_0, diabetes_1)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, diabetes_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, diabetes_1, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, diabetes_1, anaemia_0)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, diabetes_1, sex_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, diabetes_1, sex_1, anaemia_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, diabetes_1, sex_1, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, serum_sodium_6, anaemia_0)
# 5 itemset(s) from tree conditioned on items (high_blood_pressure_1, sex_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, sex_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, sex_0, anaemia_1)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, sex_0, diabetes_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, sex_0, diabetes_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, sex_0, diabetes_0, anaemia_1)
# 4 itemset(s) from tree conditioned on items (high_blood_pressure_1, sex_0, creatinine_phosphokinase_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, sex_0, creatinine_phosphokinase_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, sex_0, creatinine_phosphokinase_0, anaemia_1)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, sex_0, creatinine_phosphokinase_0, diabetes_0)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, sex_0, creatinine_phosphokinase_0, anaemia_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, sex_0, creatinine_phosphokinase_0, anaemia_0, diabetes_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, sex_0, creatinine_phosphokinase_0, anaemia_0, smoking_0)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, sex_0, anaemia_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, sex_0, anaemia_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, sex_0, anaemia_0, diabetes_0)
# 6 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, smoking_0)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, sex_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, sex_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, sex_0, anaemia_0)
# 4 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, creatinine_phosphokinase_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, creatinine_phosphokinase_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, creatinine_phosphokinase_0, sex_0)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, creatinine_phosphokinase_0, anaemia_0)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, creatinine_phosphokinase_0, anaemia_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, creatinine_phosphokinase_0, anaemia_0, sex_0)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, creatinine_phosphokinase_0, sex_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, creatinine_phosphokinase_0, sex_1, anaemia_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, creatinine_phosphokinase_0, sex_1, smoking_0)
# 4 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, anaemia_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, anaemia_1, smoking_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, anaemia_1, sex_0)
# 3 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, anaemia_1, creatinine_phosphokinase_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, anaemia_1, sex_1)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, anaemia_0)
# 2 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, sex_1)
# 0 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, sex_1, anaemia_0)
# 1 itemset(s) from tree conditioned on items (high_blood_pressure_1, diabetes_1, sex_1, smoking_0)
# 16 itemset(s) from tree conditioned on items (platelets_7)
# 0 itemset(s) from tree conditioned on items (platelets_7, anaemia_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, smoking_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, sex_1)
# 1 itemset(s) from tree conditioned on items (platelets_7, sex_1, anaemia_0)
# 2 itemset(s) from tree conditioned on items (platelets_7, sex_1, smoking_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, sex_1, smoking_0, anaemia_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, sex_1, smoking_0, high_blood_pressure_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, sex_1, high_blood_pressure_0)
# 4 itemset(s) from tree conditioned on items (platelets_7, diabetes_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, diabetes_0, anaemia_0)
# 2 itemset(s) from tree conditioned on items (platelets_7, diabetes_0, sex_1)
# 0 itemset(s) from tree conditioned on items (platelets_7, diabetes_0, sex_1, anaemia_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, diabetes_0, sex_1, high_blood_pressure_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, diabetes_0, smoking_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, diabetes_0, smoking_0, anaemia_0)
# 2 itemset(s) from tree conditioned on items (platelets_7, diabetes_0, smoking_0, sex_1)
# 0 itemset(s) from tree conditioned on items (platelets_7, diabetes_0, smoking_0, sex_1, anaemia_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, diabetes_0, smoking_0, sex_1, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, diabetes_0, smoking_0, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, diabetes_0, high_blood_pressure_0)
# 8 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, smoking_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, anaemia_0)
# 2 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, sex_1)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, sex_1, anaemia_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, sex_1, smoking_0)
# 4 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, diabetes_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, diabetes_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, diabetes_0, sex_1)
# 2 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, diabetes_0, anaemia_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, diabetes_0, anaemia_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, diabetes_0, anaemia_0, sex_1)
# 3 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, diabetes_0, serum_sodium_6)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, diabetes_0, serum_sodium_6, sex_1)
# 2 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, diabetes_0, serum_sodium_6, smoking_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, diabetes_0, serum_sodium_6, smoking_0, sex_1)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, diabetes_0, serum_sodium_6, smoking_0, anaemia_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, diabetes_0, serum_sodium_6, anaemia_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, serum_sodium_6)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, serum_sodium_6, smoking_0)
# 2 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, serum_sodium_6, sex_1)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, serum_sodium_6, sex_1, smoking_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, serum_sodium_6, sex_1, anaemia_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, serum_sodium_6, anaemia_0)
# 7 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3)
# 3 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, serum_sodium_6)
# 3 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, sex_1)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, sex_1, serum_sodium_6)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, sex_1, diabetes_1)
# 3 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, sex_1, anaemia_0)
# 4 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, smoking_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, smoking_0, serum_sodium_6)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, smoking_0, sex_1)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, smoking_0, anaemia_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, smoking_0, diabetes_1)
# 3 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, diabetes_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, diabetes_0, smoking_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, diabetes_0, sex_1)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, diabetes_0, serum_sodium_6)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, diabetes_1)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, anaemia_0)
# 4 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, sex_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, sex_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, sex_0, anaemia_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, sex_0, serum_sodium_6)
# 3 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, ejection_fraction_3, sex_0, diabetes_1)
# 5 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, sex_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, sex_0, smoking_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, sex_0, serum_sodium_6)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, sex_0, serum_sodium_6, smoking_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, sex_0, serum_sodium_6, diabetes_1)
# 3 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, sex_0, serum_sodium_6, anaemia_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, sex_0, diabetes_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, sex_0, diabetes_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, sex_0, diabetes_0, serum_sodium_6)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, sex_0, diabetes_0, anaemia_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, sex_0, anaemia_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, sex_0, diabetes_1)
# 4 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, diabetes_1)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, diabetes_1, anaemia_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, diabetes_1, serum_sodium_6)
# 2 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, diabetes_1, smoking_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, diabetes_1, smoking_0, serum_sodium_6)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, diabetes_1, smoking_0, anaemia_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_1, diabetes_1, sex_1)
# 2 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, high_blood_pressure_0, anaemia_0)
# 5 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, anaemia_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, sex_1)
# 2 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, high_blood_pressure_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, high_blood_pressure_0, sex_1)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, high_blood_pressure_0, anaemia_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, smoking_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, smoking_0, anaemia_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, smoking_0, high_blood_pressure_0)
# 2 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, smoking_0, sex_1)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, smoking_0, sex_1, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, smoking_0, sex_1, anaemia_0)
# 4 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, diabetes_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, diabetes_0, anaemia_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, diabetes_0, high_blood_pressure_0)
# 2 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, diabetes_0, sex_1)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, diabetes_0, sex_1, anaemia_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, diabetes_0, sex_1, high_blood_pressure_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, diabetes_0, smoking_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, diabetes_0, smoking_0, anaemia_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, diabetes_0, smoking_0, high_blood_pressure_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, serum_sodium_6, diabetes_0, smoking_0, sex_1)
# 6 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3)
# 0 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, smoking_0)
# 2 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, sex_1)
# 0 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, sex_1, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, sex_1, smoking_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, anaemia_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, anaemia_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, anaemia_0, high_blood_pressure_0)
# 2 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, anaemia_0, sex_1)
# 0 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, anaemia_0, sex_1, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, anaemia_0, sex_1, smoking_0)
# 4 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, serum_sodium_6)
# 0 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, serum_sodium_6, smoking_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, serum_sodium_6, sex_1)
# 2 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, serum_sodium_6, high_blood_pressure_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, serum_sodium_6, high_blood_pressure_0, sex_1)
# 1 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, serum_sodium_6, high_blood_pressure_0, smoking_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, serum_sodium_6, anaemia_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, serum_sodium_6, anaemia_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, serum_sodium_6, anaemia_0, sex_1)
# 2 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, serum_sodium_6, anaemia_0, high_blood_pressure_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, serum_sodium_6, anaemia_0, high_blood_pressure_0, sex_1)
# 1 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, serum_sodium_6, anaemia_0, high_blood_pressure_0, smoking_0)
# 5 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, diabetes_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, diabetes_0, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, diabetes_0, smoking_0)
# 2 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, diabetes_0, sex_1)
# 0 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, diabetes_0, sex_1, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, diabetes_0, sex_1, smoking_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, diabetes_0, anaemia_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, diabetes_0, anaemia_0, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, diabetes_0, anaemia_0, smoking_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, diabetes_0, anaemia_0, sex_1)
# 4 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, diabetes_0, serum_sodium_6)
# 0 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, diabetes_0, serum_sodium_6, smoking_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, diabetes_0, serum_sodium_6, high_blood_pressure_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, diabetes_0, serum_sodium_6, anaemia_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, diabetes_0, serum_sodium_6, sex_1)
# 0 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, diabetes_0, serum_sodium_6, sex_1, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, diabetes_0, serum_sodium_6, sex_1, smoking_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, ejection_fraction_3, diabetes_0, serum_sodium_6, sex_1, anaemia_0)
# 12 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, serum_sodium_6)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, high_blood_pressure_0)
# 2 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, anaemia_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, anaemia_0, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, anaemia_0, serum_sodium_6)
# 3 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, diabetes_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, diabetes_0, anaemia_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, diabetes_0, serum_sodium_6)
# 2 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, diabetes_0, high_blood_pressure_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, diabetes_0, high_blood_pressure_0, anaemia_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, diabetes_0, high_blood_pressure_0, serum_sodium_6)
# 4 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, smoking_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, smoking_0, anaemia_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, smoking_0, serum_sodium_6)
# 2 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, smoking_0, diabetes_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, smoking_0, diabetes_0, serum_sodium_6)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, smoking_0, diabetes_0, anaemia_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, smoking_0, high_blood_pressure_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, smoking_0, high_blood_pressure_0, anaemia_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, smoking_0, high_blood_pressure_0, diabetes_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, smoking_0, high_blood_pressure_0, serum_sodium_6)
# 5 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, sex_1)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, sex_1, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, sex_1, serum_sodium_6)
# 2 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, sex_1, diabetes_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, sex_1, diabetes_0, serum_sodium_6)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, sex_1, diabetes_0, high_blood_pressure_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, sex_1, anaemia_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, sex_1, anaemia_0, serum_sodium_6)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, sex_1, anaemia_0, high_blood_pressure_0)
# 2 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, sex_1, anaemia_0, diabetes_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, sex_1, anaemia_0, diabetes_0, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, sex_1, anaemia_0, diabetes_0, serum_sodium_6)
# 4 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, sex_1, smoking_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, sex_1, smoking_0, serum_sodium_6)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, sex_1, smoking_0, diabetes_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, sex_1, smoking_0, high_blood_pressure_0)
# 7 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, sex_1, smoking_0, anaemia_0)
# 6 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, ejection_fraction_3)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, ejection_fraction_3, smoking_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, ejection_fraction_3, anaemia_0)
# 2 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, ejection_fraction_3, high_blood_pressure_0)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, ejection_fraction_3, high_blood_pressure_0, anaemia_0)
# 1 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, ejection_fraction_3, high_blood_pressure_0, smoking_0)
# 3 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, ejection_fraction_3, serum_sodium_6)
# 0 itemset(s) from tree conditioned on items (platelets_7, serum_creatinine_3, ejection_fraction_3, serum_sodium_6, smoking_0)
# ...
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, high_blood_pressure_0, serum_sodium_6, platelets_7, smoking_0)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, high_blood_pressure_0, serum_sodium_6, platelets_7, diabetes_0)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, high_blood_pressure_0, serum_sodium_6, platelets_7, ejection_fraction_3)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, high_blood_pressure_0, serum_sodium_6, ejection_fraction_3)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, high_blood_pressure_0, ejection_fraction_3)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, serum_creatinine_4)
# 15 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, age_2)
# 2 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, ejection_fraction_3)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, ejection_fraction_3, smoking_0)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, ejection_fraction_3, serum_sodium_6)
# 8 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, anaemia_1)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, anaemia_1, ejection_fraction_3)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, anaemia_1, sex_1)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, anaemia_1, sex_1, ejection_fraction_3)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, anaemia_1, sex_1, serum_sodium_6)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, anaemia_1, sex_1, diabetes_0)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, anaemia_1, smoking_0)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, anaemia_1, diabetes_0)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, anaemia_1, serum_sodium_6)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, anaemia_1, serum_sodium_6, diabetes_0)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, anaemia_1, serum_sodium_6, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, anaemia_1, serum_sodium_6, ejection_fraction_3)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, anaemia_1, high_blood_pressure_0)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, anaemia_1, sex_0)
# 15 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, anaemia_1, platelets_7)
# 9 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, diabetes_1)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, diabetes_1, smoking_0)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, diabetes_1, ejection_fraction_3)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, diabetes_1, high_blood_pressure_1)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, diabetes_1, anaemia_1)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, diabetes_1, sex_0)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, diabetes_1, anaemia_0)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, diabetes_1, serum_sodium_6)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, diabetes_1, high_blood_pressure_0)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, diabetes_1, platelets_7)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, platelets_9)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, age_3)
# 5 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, serum_creatinine_5)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, serum_creatinine_5, anaemia_1)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, serum_creatinine_5, sex_1)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, serum_creatinine_5, diabetes_0)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, serum_creatinine_5, serum_sodium_6)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, serum_creatinine_5, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, ejection_fraction_6)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, platelets_5)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, sex_0)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, sex_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, sex_0, platelets_7)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, sex_0, ejection_fraction_3)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, sex_0, anaemia_0)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, sex_0, anaemia_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, sex_0, anaemia_0, ejection_fraction_3)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, sex_0, anaemia_0, platelets_7)
# 4 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, sex_0, serum_sodium_6)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, sex_0, serum_sodium_6, ejection_fraction_3)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, sex_0, serum_sodium_6, smoking_0)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, sex_0, serum_sodium_6, anaemia_0)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, sex_0, serum_sodium_6, platelets_7)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, sex_0, diabetes_0)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, sex_0, high_blood_pressure_0)
# 15 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, age_7)
# 63 itemset(s) from tree conditioned on items (creatinine_phosphokinase_4, age_4)
# 8 itemset(s) from tree conditioned on items (platelets_2)
# 0 itemset(s) from tree conditioned on items (platelets_2, smoking_1)
# 1 itemset(s) from tree conditioned on items (platelets_2, anaemia_0)
# 3 itemset(s) from tree conditioned on items (platelets_2, high_blood_pressure_0)
# 7 itemset(s) from tree conditioned on items (platelets_2, sex_1)
# 15 itemset(s) from tree conditioned on items (platelets_2, age_3)
# 15 itemset(s) from tree conditioned on items (platelets_2, diabetes_0)
# 15 itemset(s) from tree conditioned on items (platelets_2, serum_creatinine_2)
# 31 itemset(s) from tree conditioned on items (platelets_2, ejection_fraction_3)
# 8 itemset(s) from tree conditioned on items (platelets_14)
# 0 itemset(s) from tree conditioned on items (platelets_14, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (platelets_14, smoking_0)
# 3 itemset(s) from tree conditioned on items (platelets_14, ejection_fraction_1)
# 3 itemset(s) from tree conditioned on items (platelets_14, creatinine_phosphokinase_0)
# 7 itemset(s) from tree conditioned on items (platelets_14, diabetes_1)
# 15 itemset(s) from tree conditioned on items (platelets_14, anaemia_0)
# 31 itemset(s) from tree conditioned on items (platelets_14, sex_1)
# 3 itemset(s) from tree conditioned on items (platelets_14, serum_sodium_7)
# 8 itemset(s) from tree conditioned on items (serum_creatinine_11)
# 0 itemset(s) from tree conditioned on items (serum_creatinine_11, smoking_0)
# 1 itemset(s) from tree conditioned on items (serum_creatinine_11, sex_0)
# 1 itemset(s) from tree conditioned on items (serum_creatinine_11, creatinine_phosphokinase_0)
# 1 itemset(s) from tree conditioned on items (serum_creatinine_11, platelets_6)
# 3 itemset(s) from tree conditioned on items (serum_creatinine_11, high_blood_pressure_1)
# 7 itemset(s) from tree conditioned on items (serum_creatinine_11, serum_sodium_6)
# 15 itemset(s) from tree conditioned on items (serum_creatinine_11, anaemia_0)
# 31 itemset(s) from tree conditioned on items (serum_creatinine_11, diabetes_0)
# 17 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, sex_1)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, smoking_0)
# 4 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, serum_sodium_7)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, serum_sodium_7, smoking_0)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, serum_sodium_7, sex_1)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, serum_sodium_7, high_blood_pressure_0)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, serum_sodium_7, diabetes_0)
# 4 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, diabetes_1)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, diabetes_1, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, diabetes_1, smoking_0)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, diabetes_1, sex_1)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, diabetes_1, anaemia_0)
# 6 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, ejection_fraction_3)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, ejection_fraction_3, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, ejection_fraction_3, diabetes_1)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, ejection_fraction_3, serum_sodium_7)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, ejection_fraction_3, smoking_0)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, ejection_fraction_3, sex_1)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, ejection_fraction_3, anaemia_0)
# 5 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, anaemia_1)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, anaemia_1, sex_1)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, anaemia_1, serum_sodium_7)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, anaemia_1, smoking_0)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, anaemia_1, high_blood_pressure_0)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, anaemia_1, diabetes_0)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, platelets_6)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, diabetes_0)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, diabetes_0, sex_1)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, diabetes_0, smoking_0)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, diabetes_0, high_blood_pressure_0)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, age_2)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, serum_creatinine_1)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, smoking_1)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, anaemia_0)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, platelets_7)
# 15 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, serum_creatinine_3)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, serum_sodium_6)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_11, sex_0)
# 7 itemset(s) from tree conditioned on items (serum_sodium_3)
# 0 itemset(s) from tree conditioned on items (serum_sodium_3, diabetes_1)
# 1 itemset(s) from tree conditioned on items (serum_sodium_3, smoking_0)
# 3 itemset(s) from tree conditioned on items (serum_sodium_3, creatinine_phosphokinase_4)
# 3 itemset(s) from tree conditioned on items (serum_sodium_3, high_blood_pressure_1)
# 3 itemset(s) from tree conditioned on items (serum_sodium_3, platelets_7)
# 7 itemset(s) from tree conditioned on items (serum_sodium_3, sex_0)
# 15 itemset(s) from tree conditioned on items (serum_sodium_3, anaemia_0)
# 31 itemset(s) from tree conditioned on items (creatinine_phosphokinase_10)
# 9 itemset(s) from tree conditioned on items (creatinine_phosphokinase_14)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_14, serum_creatinine_2)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_14, ejection_fraction_3)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_14, smoking_0)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_14, age_3)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_14, serum_sodium_8)
# 15 itemset(s) from tree conditioned on items (creatinine_phosphokinase_14, sex_0)
# 31 itemset(s) from tree conditioned on items (creatinine_phosphokinase_14, diabetes_1)
# 63 itemset(s) from tree conditioned on items (creatinine_phosphokinase_14, anaemia_1)
# 127 itemset(s) from tree conditioned on items (creatinine_phosphokinase_14, high_blood_pressure_0)
# 8 itemset(s) from tree conditioned on items (creatinine_phosphokinase_15)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_15, serum_sodium_7)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_15, anaemia_0)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_15, ejection_fraction_2)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_15, age_0)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_15, high_blood_pressure_0)
# 15 itemset(s) from tree conditioned on items (creatinine_phosphokinase_15, sex_1)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_15, smoking_0)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_15, diabetes_0)
# 13 itemset(s) from tree conditioned on items (creatinine_phosphokinase_7)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_7, anaemia_0)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_7, serum_creatinine_7)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_7, platelets_7)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_7, smoking_1)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_7, ejection_fraction_3)
# 15 itemset(s) from tree conditioned on items (creatinine_phosphokinase_7, high_blood_pressure_0)
# 31 itemset(s) from tree conditioned on items (creatinine_phosphokinase_7, sex_1)
# 0 itemset(s) from tree conditioned on items (creatinine_phosphokinase_7, diabetes_0)
# 1 itemset(s) from tree conditioned on items (creatinine_phosphokinase_7, serum_sodium_8)
# 3 itemset(s) from tree conditioned on items (creatinine_phosphokinase_7, serum_creatinine_2)
# 7 itemset(s) from tree conditioned on items (creatinine_phosphokinase_7, high_blood_pressure_1)
# 15 itemset(s) from tree conditioned on items (creatinine_phosphokinase_7, sex_0)
# 31 itemset(s) from tree conditioned on items (creatinine_phosphokinase_7, smoking_0)
# 15 itemset(s) from tree conditioned on items (creatinine_phosphokinase_17)
# 15 itemset(s) from tree conditioned on items (platelets_15)
# 15 itemset(s) from tree conditioned on items (creatinine_phosphokinase_12)
# 61683 patterns

# %%
MIN_CONF: float = 0.1
rules = {}
for name, p in patterns.items():
    print("-------------{}-------------".format(name))
    rules[name] = g20PM.get_rules(p, MIN_CONF)
# Out:
# -------------Dummified by width-------------
# 	found 553827 rules

# %% [markdown]
# # Quality evaluation per support

# %%
for name, r in rules.items():
    print("-------------{}-------------".format(name))
    nr_rules_sp = g20PM.analyse_per_metric(r, 'support', var_min_sup)
    ds.plot_line(var_min_sup, nr_rules_sp, title='Nr rules x Support', xlabel='support',
                 ylabel='Nr. rules', percentage=False)
# Out:
# -------------Dummified by width-------------
# Analyse per support...

# %% [markdown]
# Quality evaluation per confidence

# %%
var_min_conf = [i * MIN_CONF for i in range(10, 5, -1)]
for name, r in rules.items():
    print("-------------{}-------------".format(name))
    nr_rules_cf = g20PM.analyse_per_metric(r, 'confidence', var_min_conf)
    ds.plot_line(var_min_conf, nr_rules_cf, title='Nr Rules x Confidence', xlabel='confidence', ylabel='Nr Rules', percentage=False)
# Out:
# -------------Dummified by width-------------
# Analyse per confidence...
