# %%
import numpy as np
import pandas as pd
import g20_functions as g20
import g20_Pattern_Mining as g20PM
import ds_functions as ds
import random as rd

# %%
data = g20.loadToxicBool()
data.pop(1024)

#
for i in range(300):
    data.pop(i)
    
for i in range(320,700):
    data.pop(i)
    
for i in range(720,1017):
    data.pop(i)
    
values = {'Original': data}


len(data.columns)
rd.randint(0,len(data.columns))
np.shape(data)
data
# Out:
#        300    301    302    303    304    305    306    307    308    309   \
# 0     False  False  False  False  False  False  False  False  False  False
# 1     False  False  False  False  False  False  False  False  False  False
# 2     False  False  False  False  False  False  False  False  False   True
# 3     False  False  False  False  False  False  False  False  False  False
# 4     False  False  False  False  False  False  False  False  False  False
# ...     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 8987  False  False  False  False  False  False  False  False  False  False
# 8988  False  False  False  False   True  False  False  False  False  False
# 8989  False  False  False  False  False  False  False  False  False  False
# 8990  False   True  False  False  False  False  False  False  False  False
# 8991  False  False  False  False  False  False  False  False  False  False
#
#       ...   717    718    719    1017   1018   1019   1020   1021   1022  \
# 0     ...  False  False  False  False  False  False  False  False  False
# 1     ...  False  False  False  False  False  False  False  False  False
# 2     ...  False  False  False   True  False  False  False  False  False
# 3     ...  False  False  False  False  False  False  False  False  False
# 4     ...  False  False  False  False  False  False  False  False  False
# ...   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 8987  ...  False  False  False  False   True  False  False  False  False
# 8988  ...  False  False  False  False   True  False  False  False  False
# 8989  ...  False  False  False  False  False  False  False  False   True
# 8990  ...  False  False   True  False  False  False  False  False  False
# 8991  ...  False   True  False  False  False  False  False  False  False
#
#        1023
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ...     ...
# 8987  False
# 8988  False
# 8989  False
# 8990  False
# 8991  False
#
# [8992 rows x 47 columns]

# %%
patterns = {}
MIN_SUP: float = 0.001
var_min_sup =[0.2, 0.1] + [i*MIN_SUP for i  in range(100, 0, -10)]
for name, data in values.items():
    print("-------------{}-------------".format(name))
    patterns[name] = g20PM.get_patterns(data,MIN_SUP)
    g20PM.plot_patterns(patterns[name],var_min_sup)
# Out:
# -------------Original-------------
# 47 itemset(s) from tree conditioned on items ()
# 9 itemset(s) from tree conditioned on items (714)
# 5 itemset(s) from tree conditioned on items (714, 1017)
# 1 itemset(s) from tree conditioned on items (714, 1017, 316)
# 0 itemset(s) from tree conditioned on items (714, 1017, 302)
# 4 itemset(s) from tree conditioned on items (714, 1017, 307)
# 0 itemset(s) from tree conditioned on items (714, 1017, 307, 302)
# 1 itemset(s) from tree conditioned on items (714, 1017, 307, 316)
# 3 itemset(s) from tree conditioned on items (714, 1017, 307, 1018)
# 0 itemset(s) from tree conditioned on items (714, 1017, 307, 1018, 302)
# 1 itemset(s) from tree conditioned on items (714, 1017, 307, 1018, 316)
# 0 itemset(s) from tree conditioned on items (714, 1017, 307, 1018, 702)
# 2 itemset(s) from tree conditioned on items (714, 1017, 307, 702)
# 0 itemset(s) from tree conditioned on items (714, 1017, 307, 702, 302)
# 1 itemset(s) from tree conditioned on items (714, 1017, 307, 702, 316)
# 2 itemset(s) from tree conditioned on items (714, 1017, 702)
# 0 itemset(s) from tree conditioned on items (714, 1017, 702, 302)
# 1 itemset(s) from tree conditioned on items (714, 1017, 702, 316)
# 3 itemset(s) from tree conditioned on items (714, 1017, 1018)
# 0 itemset(s) from tree conditioned on items (714, 1017, 1018, 302)
# 1 itemset(s) from tree conditioned on items (714, 1017, 1018, 316)
# 2 itemset(s) from tree conditioned on items (714, 1017, 1018, 702)
# 0 itemset(s) from tree conditioned on items (714, 1017, 1018, 702, 302)
# 1 itemset(s) from tree conditioned on items (714, 1017, 1018, 702, 316)
# 1 itemset(s) from tree conditioned on items (714, 702)
# 2 itemset(s) from tree conditioned on items (714, 316)
# 1 itemset(s) from tree conditioned on items (714, 316, 702)
# 0 itemset(s) from tree conditioned on items (714, 316, 302)
# 0 itemset(s) from tree conditioned on items (714, 302)
# 3 itemset(s) from tree conditioned on items (714, 1018)
# 0 itemset(s) from tree conditioned on items (714, 1018, 316)
# 1 itemset(s) from tree conditioned on items (714, 1018, 302)
# 2 itemset(s) from tree conditioned on items (714, 1018, 702)
# 0 itemset(s) from tree conditioned on items (714, 1018, 702, 302)
# 1 itemset(s) from tree conditioned on items (714, 1018, 702, 316)
# 6 itemset(s) from tree conditioned on items (714, 304)
# 0 itemset(s) from tree conditioned on items (714, 304, 702)
# 1 itemset(s) from tree conditioned on items (714, 304, 302)
# 2 itemset(s) from tree conditioned on items (714, 304, 316)
# 0 itemset(s) from tree conditioned on items (714, 304, 316, 702)
# 1 itemset(s) from tree conditioned on items (714, 304, 316, 302)
# 4 itemset(s) from tree conditioned on items (714, 304, 1018)
# 0 itemset(s) from tree conditioned on items (714, 304, 1018, 702)
# 1 itemset(s) from tree conditioned on items (714, 304, 1018, 302)
# 3 itemset(s) from tree conditioned on items (714, 304, 1018, 316)
# 0 itemset(s) from tree conditioned on items (714, 304, 1018, 316, 702)
# 1 itemset(s) from tree conditioned on items (714, 304, 1018, 316, 302)
# 3 itemset(s) from tree conditioned on items (714, 304, 1018, 316, 706)
# 3 itemset(s) from tree conditioned on items (714, 304, 1018, 706)
# 3 itemset(s) from tree conditioned on items (714, 304, 706)
# 0 itemset(s) from tree conditioned on items (714, 304, 706, 702)
# 1 itemset(s) from tree conditioned on items (714, 304, 706, 316)
# 2 itemset(s) from tree conditioned on items (714, 304, 706, 302)
# 0 itemset(s) from tree conditioned on items (714, 304, 706, 302, 316)
# 1 itemset(s) from tree conditioned on items (714, 304, 706, 302, 702)
# 4 itemset(s) from tree conditioned on items (714, 304, 711)
# 0 itemset(s) from tree conditioned on items (714, 304, 711, 706)
# 1 itemset(s) from tree conditioned on items (714, 304, 711, 316)
# 3 itemset(s) from tree conditioned on items (714, 304, 711, 702)
# 3 itemset(s) from tree conditioned on items (714, 304, 711, 302)
# 0 itemset(s) from tree conditioned on items (714, 304, 711, 302, 702)
# 1 itemset(s) from tree conditioned on items (714, 304, 711, 302, 316)
# 3 itemset(s) from tree conditioned on items (714, 304, 711, 302, 706)
# 4 itemset(s) from tree conditioned on items (714, 307)
# 0 itemset(s) from tree conditioned on items (714, 307, 302)
# 1 itemset(s) from tree conditioned on items (714, 307, 316)
# 2 itemset(s) from tree conditioned on items (714, 307, 1018)
# 0 itemset(s) from tree conditioned on items (714, 307, 1018, 316)
# 1 itemset(s) from tree conditioned on items (714, 307, 1018, 302)
# 3 itemset(s) from tree conditioned on items (714, 307, 702)
# 0 itemset(s) from tree conditioned on items (714, 307, 702, 316)
# 2 itemset(s) from tree conditioned on items (714, 307, 702, 1018)
# 0 itemset(s) from tree conditioned on items (714, 307, 702, 1018, 316)
# 1 itemset(s) from tree conditioned on items (714, 307, 702, 1018, 302)
# 1 itemset(s) from tree conditioned on items (714, 307, 702, 302)
# 6 itemset(s) from tree conditioned on items (714, 711)
# 0 itemset(s) from tree conditioned on items (714, 711, 316)
# 1 itemset(s) from tree conditioned on items (714, 711, 302)
# 3 itemset(s) from tree conditioned on items (714, 711, 1018)
# 0 itemset(s) from tree conditioned on items (714, 711, 1018, 316)
# 1 itemset(s) from tree conditioned on items (714, 711, 1018, 302)
# 2 itemset(s) from tree conditioned on items (714, 711, 1018, 702)
# 0 itemset(s) from tree conditioned on items (714, 711, 1018, 702, 316)
# 1 itemset(s) from tree conditioned on items (714, 711, 1018, 702, 302)
# 4 itemset(s) from tree conditioned on items (714, 711, 307)
# 0 itemset(s) from tree conditioned on items (714, 711, 307, 316)
# 1 itemset(s) from tree conditioned on items (714, 711, 307, 302)
# 3 itemset(s) from tree conditioned on items (714, 711, 307, 1018)
# 1 itemset(s) from tree conditioned on items (714, 711, 307, 702)
# 2 itemset(s) from tree conditioned on items (714, 711, 702)
# 0 itemset(s) from tree conditioned on items (714, 711, 702, 316)
# 1 itemset(s) from tree conditioned on items (714, 711, 702, 302)
# 4 itemset(s) from tree conditioned on items (714, 711, 1017)
# 0 itemset(s) from tree conditioned on items (714, 711, 1017, 302)
# 1 itemset(s) from tree conditioned on items (714, 711, 1017, 316)
# 3 itemset(s) from tree conditioned on items (714, 711, 1017, 702)
# 3 itemset(s) from tree conditioned on items (714, 711, 1017, 1018)
# 7 itemset(s) from tree conditioned on items (714, 706)
# 0 itemset(s) from tree conditioned on items (714, 706, 702)
# 1 itemset(s) from tree conditioned on items (714, 706, 316)
# 2 itemset(s) from tree conditioned on items (714, 706, 302)
# 0 itemset(s) from tree conditioned on items (714, 706, 302, 702)
# 1 itemset(s) from tree conditioned on items (714, 706, 302, 316)
# 3 itemset(s) from tree conditioned on items (714, 706, 1018)
# 0 itemset(s) from tree conditioned on items (714, 706, 1018, 702)
# 1 itemset(s) from tree conditioned on items (714, 706, 1018, 316)
# 2 itemset(s) from tree conditioned on items (714, 706, 1018, 302)
# 0 itemset(s) from tree conditioned on items (714, 706, 1018, 302, 702)
# 1 itemset(s) from tree conditioned on items (714, 706, 1018, 302, 316)
# 4 itemset(s) from tree conditioned on items (714, 706, 1017)
# 0 itemset(s) from tree conditioned on items (714, 706, 1017, 702)
# 1 itemset(s) from tree conditioned on items (714, 706, 1017, 316)
# 1 itemset(s) from tree conditioned on items (714, 706, 1017, 302)
# 1 itemset(s) from tree conditioned on items (714, 706, 1017, 1018)
# 4 itemset(s) from tree conditioned on items (714, 706, 711)
# 0 itemset(s) from tree conditioned on items (714, 706, 711, 316)
# 1 itemset(s) from tree conditioned on items (714, 706, 711, 702)
# 2 itemset(s) from tree conditioned on items (714, 706, 711, 302)
# 0 itemset(s) from tree conditioned on items (714, 706, 711, 302, 702)
# 1 itemset(s) from tree conditioned on items (714, 706, 711, 302, 316)
# 7 itemset(s) from tree conditioned on items (714, 706, 711, 1018)
# 5 itemset(s) from tree conditioned on items (714, 706, 307)
# 0 itemset(s) from tree conditioned on items (714, 706, 307, 702)
# 1 itemset(s) from tree conditioned on items (714, 706, 307, 316)
# 1 itemset(s) from tree conditioned on items (714, 706, 307, 1018)
# 1 itemset(s) from tree conditioned on items (714, 706, 307, 1017)
# 3 itemset(s) from tree conditioned on items (714, 706, 307, 302)
# 25 itemset(s) from tree conditioned on items (318)
# 5 itemset(s) from tree conditioned on items (318, 714)
# 0 itemset(s) from tree conditioned on items (318, 714, 702)
# 1 itemset(s) from tree conditioned on items (318, 714, 302)
# 3 itemset(s) from tree conditioned on items (318, 714, 316)
# 3 itemset(s) from tree conditioned on items (318, 714, 317)
# 0 itemset(s) from tree conditioned on items (318, 714, 317, 702)
# 1 itemset(s) from tree conditioned on items (318, 714, 317, 302)
# 1 itemset(s) from tree conditioned on items (318, 714, 317, 316)
# 0 itemset(s) from tree conditioned on items (318, 714, 310)
# 4 itemset(s) from tree conditioned on items (318, 316)
# 0 itemset(s) from tree conditioned on items (318, 316, 702)
# 1 itemset(s) from tree conditioned on items (318, 316, 302)
# 2 itemset(s) from tree conditioned on items (318, 316, 317)
# 0 itemset(s) from tree conditioned on items (318, 316, 317, 302)
# 1 itemset(s) from tree conditioned on items (318, 316, 317, 702)
# 3 itemset(s) from tree conditioned on items (318, 316, 310)
# 0 itemset(s) from tree conditioned on items (318, 316, 310, 317)
# 1 itemset(s) from tree conditioned on items (318, 316, 310, 702)
# 1 itemset(s) from tree conditioned on items (318, 316, 310, 302)
# 0 itemset(s) from tree conditioned on items (318, 702)
# 3 itemset(s) from tree conditioned on items (318, 302)
# 0 itemset(s) from tree conditioned on items (318, 302, 702)
# 1 itemset(s) from tree conditioned on items (318, 302, 317)
# 2 itemset(s) from tree conditioned on items (318, 302, 310)
# 0 itemset(s) from tree conditioned on items (318, 302, 310, 317)
# 1 itemset(s) from tree conditioned on items (318, 302, 310, 702)
# 2 itemset(s) from tree conditioned on items (318, 317)
# 1 itemset(s) from tree conditioned on items (318, 317, 702)
# 0 itemset(s) from tree conditioned on items (318, 317, 310)
# 5 itemset(s) from tree conditioned on items (318, 1018)
# 0 itemset(s) from tree conditioned on items (318, 1018, 702)
# 1 itemset(s) from tree conditioned on items (318, 1018, 317)
# 3 itemset(s) from tree conditioned on items (318, 1018, 302)
# 4 itemset(s) from tree conditioned on items (318, 1018, 316)
# 0 itemset(s) from tree conditioned on items (318, 1018, 316, 702)
# 1 itemset(s) from tree conditioned on items (318, 1018, 316, 317)
# 3 itemset(s) from tree conditioned on items (318, 1018, 316, 302)
# 0 itemset(s) from tree conditioned on items (318, 1018, 316, 310)
# 3 itemset(s) from tree conditioned on items (318, 1018, 310)
# 0 itemset(s) from tree conditioned on items (318, 1018, 310, 317)
# 1 itemset(s) from tree conditioned on items (318, 1018, 310, 702)
# 3 itemset(s) from tree conditioned on items (318, 1018, 310, 302)
# 7 itemset(s) from tree conditioned on items (318, 304)
# 0 itemset(s) from tree conditioned on items (318, 304, 317)
# 1 itemset(s) from tree conditioned on items (318, 304, 702)
# 2 itemset(s) from tree conditioned on items (318, 304, 302)
# 0 itemset(s) from tree conditioned on items (318, 304, 302, 317)
# 1 itemset(s) from tree conditioned on items (318, 304, 302, 702)
# 3 itemset(s) from tree conditioned on items (318, 304, 1018)
# 0 itemset(s) from tree conditioned on items (318, 304, 1018, 702)
# 1 itemset(s) from tree conditioned on items (318, 304, 1018, 317)
# 3 itemset(s) from tree conditioned on items (318, 304, 1018, 302)
# 4 itemset(s) from tree conditioned on items (318, 304, 316)
# 0 itemset(s) from tree conditioned on items (318, 304, 316, 317)
# 1 itemset(s) from tree conditioned on items (318, 304, 316, 702)
# 3 itemset(s) from tree conditioned on items (318, 304, 316, 1018)
# 7 itemset(s) from tree conditioned on items (318, 304, 316, 302)
# 2 itemset(s) from tree conditioned on items (318, 304, 310)
# 0 itemset(s) from tree conditioned on items (318, 304, 310, 317)
# 1 itemset(s) from tree conditioned on items (318, 304, 310, 702)
# 4 itemset(s) from tree conditioned on items (318, 304, 711)
# 0 itemset(s) from tree conditioned on items (318, 304, 711, 316)
# 0 itemset(s) from tree conditioned on items (318, 304, 711, 302)
# 0 itemset(s) from tree conditioned on items (318, 304, 711, 702)
# 1 itemset(s) from tree conditioned on items (318, 304, 711, 317)
# 6 itemset(s) from tree conditioned on items (318, 718)
# 0 itemset(s) from tree conditioned on items (318, 718, 702)
# 1 itemset(s) from tree conditioned on items (318, 718, 302)
# 1 itemset(s) from tree conditioned on items (318, 718, 304)
# 3 itemset(s) from tree conditioned on items (318, 718, 1018)
# 1 itemset(s) from tree conditioned on items (318, 718, 317)
# 1 itemset(s) from tree conditioned on items (318, 718, 711)
# 3 itemset(s) from tree conditioned on items (318, 712)
# 0 itemset(s) from tree conditioned on items (318, 712, 302)
# 0 itemset(s) from tree conditioned on items (318, 712, 316)
# 0 itemset(s) from tree conditioned on items (318, 712, 702)
# 0 itemset(s) from tree conditioned on items (318, 719)
# 0 itemset(s) from tree conditioned on items (318, 319)
# 1 itemset(s) from tree conditioned on items (318, 310)
# 4 itemset(s) from tree conditioned on items (318, 700)
# 0 itemset(s) from tree conditioned on items (318, 700, 702)
# 0 itemset(s) from tree conditioned on items (318, 700, 316)
# 0 itemset(s) from tree conditioned on items (318, 700, 310)
# 0 itemset(s) from tree conditioned on items (318, 700, 306)
# 4 itemset(s) from tree conditioned on items (318, 301)
# 0 itemset(s) from tree conditioned on items (318, 301, 317)
# 1 itemset(s) from tree conditioned on items (318, 301, 310)
# 2 itemset(s) from tree conditioned on items (318, 301, 702)
# 0 itemset(s) from tree conditioned on items (318, 301, 702, 310)
# 0 itemset(s) from tree conditioned on items (318, 301, 702, 317)
# 0 itemset(s) from tree conditioned on items (318, 301, 302)
# 5 itemset(s) from tree conditioned on items (318, 711)
# 0 itemset(s) from tree conditioned on items (318, 711, 702)
# 2 itemset(s) from tree conditioned on items (318, 711, 302)
# 0 itemset(s) from tree conditioned on items (318, 711, 302, 702)
# 1 itemset(s) from tree conditioned on items (318, 711, 302, 316)
# 3 itemset(s) from tree conditioned on items (318, 711, 1018)
# 0 itemset(s) from tree conditioned on items (318, 711, 1018, 702)
# 3 itemset(s) from tree conditioned on items (318, 711, 1018, 302)
# 1 itemset(s) from tree conditioned on items (318, 711, 1018, 316)
# 1 itemset(s) from tree conditioned on items (318, 711, 316)
# 4 itemset(s) from tree conditioned on items (318, 711, 317)
# 0 itemset(s) from tree conditioned on items (318, 711, 317, 316)
# 1 itemset(s) from tree conditioned on items (318, 711, 317, 1018)
# 1 itemset(s) from tree conditioned on items (318, 711, 317, 302)
# 3 itemset(s) from tree conditioned on items (318, 711, 317, 702)
# 3 itemset(s) from tree conditioned on items (318, 1017)
# 0 itemset(s) from tree conditioned on items (318, 1017, 702)
# 1 itemset(s) from tree conditioned on items (318, 1017, 1018)
# 1 itemset(s) from tree conditioned on items (318, 1017, 302)
# 2 itemset(s) from tree conditioned on items (318, 308)
# 0 itemset(s) from tree conditioned on items (318, 308, 702)
# 0 itemset(s) from tree conditioned on items (318, 308, 302)
# 3 itemset(s) from tree conditioned on items (318, 307)
# 0 itemset(s) from tree conditioned on items (318, 307, 302)
# 1 itemset(s) from tree conditioned on items (318, 307, 316)
# 3 itemset(s) from tree conditioned on items (318, 307, 702)
# 0 itemset(s) from tree conditioned on items (318, 704)
# 5 itemset(s) from tree conditioned on items (318, 709)
# 0 itemset(s) from tree conditioned on items (318, 709, 316)
# 1 itemset(s) from tree conditioned on items (318, 709, 302)
# 0 itemset(s) from tree conditioned on items (318, 709, 317)
# 0 itemset(s) from tree conditioned on items (318, 709, 702)
# 3 itemset(s) from tree conditioned on items (318, 709, 711)
# 1 itemset(s) from tree conditioned on items (318, 306)
# 7 itemset(s) from tree conditioned on items (318, 706)
# 0 itemset(s) from tree conditioned on items (318, 706, 702)
# 3 itemset(s) from tree conditioned on items (318, 706, 1018)
# 4 itemset(s) from tree conditioned on items (318, 706, 317)
# 0 itemset(s) from tree conditioned on items (318, 706, 317, 702)
# 1 itemset(s) from tree conditioned on items (318, 706, 317, 1018)
# 1 itemset(s) from tree conditioned on items (318, 706, 317, 304)
# 3 itemset(s) from tree conditioned on items (318, 706, 317, 316)
# 1 itemset(s) from tree conditioned on items (318, 706, 316)
# 3 itemset(s) from tree conditioned on items (318, 706, 304)
# 0 itemset(s) from tree conditioned on items (318, 706, 304, 702)
# 1 itemset(s) from tree conditioned on items (318, 706, 304, 1018)
# 1 itemset(s) from tree conditioned on items (318, 706, 304, 316)
# 3 itemset(s) from tree conditioned on items (318, 706, 302)
# 5 itemset(s) from tree conditioned on items (318, 706, 711)
# 0 itemset(s) from tree conditioned on items (318, 706, 711, 702)
# 1 itemset(s) from tree conditioned on items (318, 706, 711, 302)
# 1 itemset(s) from tree conditioned on items (318, 706, 711, 304)
# 1 itemset(s) from tree conditioned on items (318, 706, 711, 1018)
# 3 itemset(s) from tree conditioned on items (318, 706, 711, 316)
# 0 itemset(s) from tree conditioned on items (318, 314)
# 1 itemset(s) from tree conditioned on items (318, 305)
# 0 itemset(s) from tree conditioned on items (318, 713)
# 5 itemset(s) from tree conditioned on items (1017)
# 1 itemset(s) from tree conditioned on items (1017, 316)
# 2 itemset(s) from tree conditioned on items (1017, 1018)
# 1 itemset(s) from tree conditioned on items (1017, 1018, 316)
# 0 itemset(s) from tree conditioned on items (1017, 1018, 702)
# 0 itemset(s) from tree conditioned on items (1017, 702)
# 4 itemset(s) from tree conditioned on items (1017, 711)
# 0 itemset(s) from tree conditioned on items (1017, 711, 702)
# 1 itemset(s) from tree conditioned on items (1017, 711, 316)
# 3 itemset(s) from tree conditioned on items (1017, 711, 1018)
# 0 itemset(s) from tree conditioned on items (1017, 711, 1018, 702)
# 1 itemset(s) from tree conditioned on items (1017, 711, 1018, 316)
# 2 itemset(s) from tree conditioned on items (1017, 711, 1018, 302)
# 0 itemset(s) from tree conditioned on items (1017, 711, 1018, 302, 702)
# 1 itemset(s) from tree conditioned on items (1017, 711, 1018, 302, 316)
# 2 itemset(s) from tree conditioned on items (1017, 711, 302)
# 1 itemset(s) from tree conditioned on items (1017, 711, 302, 316)
# 0 itemset(s) from tree conditioned on items (1017, 711, 302, 702)
# 3 itemset(s) from tree conditioned on items (1017, 302)
# 1 itemset(s) from tree conditioned on items (1017, 302, 702)
# 2 itemset(s) from tree conditioned on items (1017, 302, 1018)
# 1 itemset(s) from tree conditioned on items (1017, 302, 1018, 702)
# 0 itemset(s) from tree conditioned on items (1017, 302, 1018, 316)
# 0 itemset(s) from tree conditioned on items (1017, 302, 316)
# 27 itemset(s) from tree conditioned on items (313)
# 4 itemset(s) from tree conditioned on items (313, 714)
# 2 itemset(s) from tree conditioned on items (313, 714, 316)
# 0 itemset(s) from tree conditioned on items (313, 714, 316, 302)
# 1 itemset(s) from tree conditioned on items (313, 714, 316, 702)
# 3 itemset(s) from tree conditioned on items (313, 714, 1018)
# 0 itemset(s) from tree conditioned on items (313, 714, 1018, 316)
# 1 itemset(s) from tree conditioned on items (313, 714, 1018, 702)
# 2 itemset(s) from tree conditioned on items (313, 714, 1018, 302)
# 0 itemset(s) from tree conditioned on items (313, 714, 1018, 302, 702)
# 1 itemset(s) from tree conditioned on items (313, 714, 1018, 302, 316)
# 0 itemset(s) from tree conditioned on items (313, 714, 702)
# 1 itemset(s) from tree conditioned on items (313, 714, 302)
# 5 itemset(s) from tree conditioned on items (313, 1017)
# 0 itemset(s) from tree conditioned on items (313, 1017, 714)
# 1 itemset(s) from tree conditioned on items (313, 1017, 316)
# 0 itemset(s) from tree conditioned on items (313, 1017, 702)
# 2 itemset(s) from tree conditioned on items (313, 1017, 302)
# 0 itemset(s) from tree conditioned on items (313, 1017, 302, 702)
# 0 itemset(s) from tree conditioned on items (313, 1017, 302, 316)
# 0 itemset(s) from tree conditioned on items (313, 1017, 1018)
# 1 itemset(s) from tree conditioned on items (313, 316)
# 3 itemset(s) from tree conditioned on items (313, 1018)
# 1 itemset(s) from tree conditioned on items (313, 1018, 316)
# 0 itemset(s) from tree conditioned on items (313, 1018, 702)
# 2 itemset(s) from tree conditioned on items (313, 1018, 302)
# 0 itemset(s) from tree conditioned on items (313, 1018, 302, 702)
# 1 itemset(s) from tree conditioned on items (313, 1018, 302, 316)
# 5 itemset(s) from tree conditioned on items (313, 709)
# 2 itemset(s) from tree conditioned on items (313, 709, 1018)
# 0 itemset(s) from tree conditioned on items (313, 709, 1018, 702)
# 0 itemset(s) from tree conditioned on items (313, 709, 1018, 302)
# 0 itemset(s) from tree conditioned on items (313, 709, 302)
# 1 itemset(s) from tree conditioned on items (313, 709, 702)
# 1 itemset(s) from tree conditioned on items (313, 709, 714)
# 0 itemset(s) from tree conditioned on items (313, 709, 316)
# 0 itemset(s) from tree conditioned on items (313, 702)
# 2 itemset(s) from tree conditioned on items (313, 302)
# 0 itemset(s) from tree conditioned on items (313, 302, 702)
# 1 itemset(s) from tree conditioned on items (313, 302, 316)
# 5 itemset(s) from tree conditioned on items (313, 308)
# 0 itemset(s) from tree conditioned on items (313, 308, 302)
# 1 itemset(s) from tree conditioned on items (313, 308, 702)
# 2 itemset(s) from tree conditioned on items (313, 308, 316)
# 0 itemset(s) from tree conditioned on items (313, 308, 316, 302)
# 1 itemset(s) from tree conditioned on items (313, 308, 316, 702)
# 2 itemset(s) from tree conditioned on items (313, 308, 711)
# 0 itemset(s) from tree conditioned on items (313, 308, 711, 316)
# 1 itemset(s) from tree conditioned on items (313, 308, 711, 302)
# 1 itemset(s) from tree conditioned on items (313, 308, 714)
# 6 itemset(s) from tree conditioned on items (313, 301)
# 0 itemset(s) from tree conditioned on items (313, 301, 709)
# 1 itemset(s) from tree conditioned on items (313, 301, 702)
# 2 itemset(s) from tree conditioned on items (313, 301, 302)
# 0 itemset(s) from tree conditioned on items (313, 301, 302, 709)
# 1 itemset(s) from tree conditioned on items (313, 301, 302, 702)
# 3 itemset(s) from tree conditioned on items (313, 301, 1018)
# 2 itemset(s) from tree conditioned on items (313, 301, 714)
# 0 itemset(s) from tree conditioned on items (313, 301, 714, 302)
# 0 itemset(s) from tree conditioned on items (313, 301, 714, 709)
# 0 itemset(s) from tree conditioned on items (313, 301, 316)
# 5 itemset(s) from tree conditioned on items (313, 306)
# 0 itemset(s) from tree conditioned on items (313, 306, 702)
# 1 itemset(s) from tree conditioned on items (313, 306, 1018)
# 1 itemset(s) from tree conditioned on items (313, 306, 302)
# 3 itemset(s) from tree conditioned on items (313, 306, 316)
# 7 itemset(s) from tree conditioned on items (313, 306, 314)
# 1 itemset(s) from tree conditioned on items (313, 718)
# 4 itemset(s) from tree conditioned on items (313, 307)
# 1 itemset(s) from tree conditioned on items (313, 307, 302)
# 0 itemset(s) from tree conditioned on items (313, 307, 702)
# 0 itemset(s) from tree conditioned on items (313, 307, 316)
# 1 itemset(s) from tree conditioned on items (313, 307, 706)
# 6 itemset(s) from tree conditioned on items (313, 317)
# 1 itemset(s) from tree conditioned on items (313, 317, 1018)
# 0 itemset(s) from tree conditioned on items (313, 317, 702)
# 3 itemset(s) from tree conditioned on items (313, 317, 316)
# 3 itemset(s) from tree conditioned on items (313, 317, 302)
# 0 itemset(s) from tree conditioned on items (313, 317, 302, 702)
# 3 itemset(s) from tree conditioned on items (313, 317, 302, 316)
# 1 itemset(s) from tree conditioned on items (313, 317, 302, 1018)
# 7 itemset(s) from tree conditioned on items (313, 317, 314)
# 7 itemset(s) from tree conditioned on items (313, 317, 306)
# 6 itemset(s) from tree conditioned on items (313, 706)
# 0 itemset(s) from tree conditioned on items (313, 706, 702)
# 1 itemset(s) from tree conditioned on items (313, 706, 316)
# 0 itemset(s) from tree conditioned on items (313, 706, 1018)
# 0 itemset(s) from tree conditioned on items (313, 706, 302)
# 2 itemset(s) from tree conditioned on items (313, 706, 711)
# 1 itemset(s) from tree conditioned on items (313, 706, 711, 316)
# 0 itemset(s) from tree conditioned on items (313, 706, 711, 702)
# 1 itemset(s) from tree conditioned on items (313, 706, 308)
# 6 itemset(s) from tree conditioned on items (313, 304)
# 0 itemset(s) from tree conditioned on items (313, 304, 702)
# 1 itemset(s) from tree conditioned on items (313, 304, 316)
# 2 itemset(s) from tree conditioned on items (313, 304, 706)
# 0 itemset(s) from tree conditioned on items (313, 304, 706, 702)
# 1 itemset(s) from tree conditioned on items (313, 304, 706, 316)
# 2 itemset(s) from tree conditioned on items (313, 304, 302)
# 0 itemset(s) from tree conditioned on items (313, 304, 302, 702)
# 1 itemset(s) from tree conditioned on items (313, 304, 302, 316)
# 1 itemset(s) from tree conditioned on items (313, 304, 1018)
# 7 itemset(s) from tree conditioned on items (313, 304, 711)
# 4 itemset(s) from tree conditioned on items (313, 305)
# 0 itemset(s) from tree conditioned on items (313, 305, 302)
# 1 itemset(s) from tree conditioned on items (313, 305, 316)
# 0 itemset(s) from tree conditioned on items (313, 305, 702)
# 0 itemset(s) from tree conditioned on items (313, 305, 711)
# 4 itemset(s) from tree conditioned on items (313, 711)
# 0 itemset(s) from tree conditioned on items (313, 711, 316)
# 2 itemset(s) from tree conditioned on items (313, 711, 302)
# 0 itemset(s) from tree conditioned on items (313, 711, 302, 316)
# 0 itemset(s) from tree conditioned on items (313, 711, 302, 702)
# 1 itemset(s) from tree conditioned on items (313, 711, 1018)
# 1 itemset(s) from tree conditioned on items (313, 711, 702)
# 4 itemset(s) from tree conditioned on items (313, 700)
# 0 itemset(s) from tree conditioned on items (313, 700, 711)
# 0 itemset(s) from tree conditioned on items (313, 700, 702)
# 1 itemset(s) from tree conditioned on items (313, 700, 302)
# 0 itemset(s) from tree conditioned on items (313, 700, 316)
# 15 itemset(s) from tree conditioned on items (313, 704)
# 7 itemset(s) from tree conditioned on items (313, 705)
# 0 itemset(s) from tree conditioned on items (313, 705, 702)
# 1 itemset(s) from tree conditioned on items (313, 705, 316)
# 7 itemset(s) from tree conditioned on items (313, 705, 314)
# 4 itemset(s) from tree conditioned on items (313, 705, 302)
# 0 itemset(s) from tree conditioned on items (313, 705, 302, 702)
# 1 itemset(s) from tree conditioned on items (313, 705, 302, 316)
# 7 itemset(s) from tree conditioned on items (313, 705, 302, 314)
# 3 itemset(s) from tree conditioned on items (313, 705, 302, 1018)
# 7 itemset(s) from tree conditioned on items (313, 705, 317)
# 3 itemset(s) from tree conditioned on items (313, 705, 1018)
# 5 itemset(s) from tree conditioned on items (313, 705, 717)
# 0 itemset(s) from tree conditioned on items (313, 705, 717, 702)
# 7 itemset(s) from tree conditioned on items (313, 705, 717, 302)
# 1 itemset(s) from tree conditioned on items (313, 705, 717, 1018)
# 3 itemset(s) from tree conditioned on items (313, 705, 717, 316)
# 7 itemset(s) from tree conditioned on items (313, 705, 717, 314)
# 1 itemset(s) from tree conditioned on items (313, 713)
# 6 itemset(s) from tree conditioned on items (313, 314)
# 0 itemset(s) from tree conditioned on items (313, 314, 316)
# 1 itemset(s) from tree conditioned on items (313, 314, 302)
# 2 itemset(s) from tree conditioned on items (313, 314, 702)
# 0 itemset(s) from tree conditioned on items (313, 314, 702, 316)
# 1 itemset(s) from tree conditioned on items (313, 314, 702, 302)
# 3 itemset(s) from tree conditioned on items (313, 314, 308)
# 1 itemset(s) from tree conditioned on items (313, 314, 711)
# 3 itemset(s) from tree conditioned on items (313, 314, 1018)
# 0 itemset(s) from tree conditioned on items (313, 314, 1018, 316)
# 3 itemset(s) from tree conditioned on items (313, 314, 1018, 302)
# 1 itemset(s) from tree conditioned on items (313, 314, 1018, 702)
# 1 itemset(s) from tree conditioned on items (313, 312)
# 1 itemset(s) from tree conditioned on items (313, 710)
# 7 itemset(s) from tree conditioned on items (313, 319)
# 0 itemset(s) from tree conditioned on items (313, 319, 1018)
# 1 itemset(s) from tree conditioned on items (313, 319, 302)
# 3 itemset(s) from tree conditioned on items (313, 319, 316)
# 7 itemset(s) from tree conditioned on items (313, 319, 314)
# 7 itemset(s) from tree conditioned on items (313, 319, 702)
# 15 itemset(s) from tree conditioned on items (313, 319, 705)
# 31 itemset(s) from tree conditioned on items (313, 319, 717)
# 4 itemset(s) from tree conditioned on items (313, 712)
# 0 itemset(s) from tree conditioned on items (313, 712, 302)
# 0 itemset(s) from tree conditioned on items (313, 712, 316)
# 0 itemset(s) from tree conditioned on items (313, 712, 702)
# 0 itemset(s) from tree conditioned on items (313, 712, 308)
# 5 itemset(s) from tree conditioned on items (313, 717)
# 0 itemset(s) from tree conditioned on items (313, 717, 702)
# 1 itemset(s) from tree conditioned on items (313, 717, 302)
# 3 itemset(s) from tree conditioned on items (313, 717, 1018)
# 0 itemset(s) from tree conditioned on items (313, 717, 1018, 702)
# 1 itemset(s) from tree conditioned on items (313, 717, 1018, 302)
# 3 itemset(s) from tree conditioned on items (313, 717, 1018, 316)
# 3 itemset(s) from tree conditioned on items (313, 717, 316)
# 7 itemset(s) from tree conditioned on items (313, 717, 314)
# 27 itemset(s) from tree conditioned on items (309)
# 11 itemset(s) from tree conditioned on items (309, 1017)
# 1 itemset(s) from tree conditioned on items (309, 1017, 316)
# 0 itemset(s) from tree conditioned on items (309, 1017, 702)
# 3 itemset(s) from tree conditioned on items (309, 1017, 302)
# 0 itemset(s) from tree conditioned on items (309, 1017, 302, 702)
# 1 itemset(s) from tree conditioned on items (309, 1017, 302, 711)
# 2 itemset(s) from tree conditioned on items (309, 1017, 302, 316)
# 0 itemset(s) from tree conditioned on items (309, 1017, 302, 316, 711)
# 0 itemset(s) from tree conditioned on items (309, 1017, 302, 316, 702)
# 6 itemset(s) from tree conditioned on items (309, 1017, 1018)
# 0 itemset(s) from tree conditioned on items (309, 1017, 1018, 702)
# 1 itemset(s) from tree conditioned on items (309, 1017, 1018, 304)
# 3 itemset(s) from tree conditioned on items (309, 1017, 1018, 706)
# 7 itemset(s) from tree conditioned on items (309, 1017, 1018, 316)
# 7 itemset(s) from tree conditioned on items (309, 1017, 1018, 713)
# 3 itemset(s) from tree conditioned on items (309, 1017, 1018, 711)
# 2 itemset(s) from tree conditioned on items (309, 1017, 711)
# 0 itemset(s) from tree conditioned on items (309, 1017, 711, 316)
# 1 itemset(s) from tree conditioned on items (309, 1017, 711, 702)
# 7 itemset(s) from tree conditioned on items (309, 1017, 706)
# 15 itemset(s) from tree conditioned on items (309, 1017, 304)
# 31 itemset(s) from tree conditioned on items (309, 1017, 713)
# 7 itemset(s) from tree conditioned on items (309, 1017, 710)
# 0 itemset(s) from tree conditioned on items (309, 1017, 710, 304)
# 1 itemset(s) from tree conditioned on items (309, 1017, 710, 706)
# 3 itemset(s) from tree conditioned on items (309, 1017, 710, 702)
# 7 itemset(s) from tree conditioned on items (309, 1017, 710, 1018)
# 15 itemset(s) from tree conditioned on items (309, 1017, 710, 316)
# 15 itemset(s) from tree conditioned on items (309, 1017, 710, 713)
# 31 itemset(s) from tree conditioned on items (309, 1017, 710, 711)
# 63 itemset(s) from tree conditioned on items (309, 1017, 308)
# 63 itemset(s) from tree conditioned on items (309, 1017, 315)
# 5 itemset(s) from tree conditioned on items (309, 714)
# 0 itemset(s) from tree conditioned on items (309, 714, 1017)
# 1 itemset(s) from tree conditioned on items (309, 714, 316)
# 0 itemset(s) from tree conditioned on items (309, 714, 302)
# 3 itemset(s) from tree conditioned on items (309, 714, 308)
# 3 itemset(s) from tree conditioned on items (309, 714, 702)
# 1 itemset(s) from tree conditioned on items (309, 316)
# 0 itemset(s) from tree conditioned on items (309, 702)
# 2 itemset(s) from tree conditioned on items (309, 706)
# 0 itemset(s) from tree conditioned on items (309, 706, 702)
# 1 itemset(s) from tree conditioned on items (309, 706, 316)
# 5 itemset(s) from tree conditioned on items (309, 302)
# 0 itemset(s) from tree conditioned on items (309, 302, 316)
# 1 itemset(s) from tree conditioned on items (309, 302, 702)
# 3 itemset(s) from tree conditioned on items (309, 302, 706)
# 0 itemset(s) from tree conditioned on items (309, 302, 706, 702)
# 1 itemset(s) from tree conditioned on items (309, 302, 706, 316)
# 3 itemset(s) from tree conditioned on items (309, 302, 706, 711)
# 2 itemset(s) from tree conditioned on items (309, 302, 711)
# 0 itemset(s) from tree conditioned on items (309, 302, 711, 316)
# 1 itemset(s) from tree conditioned on items (309, 302, 711, 702)
# 7 itemset(s) from tree conditioned on items (309, 302, 304)
# 8 itemset(s) from tree conditioned on items (309, 1018)
# 0 itemset(s) from tree conditioned on items (309, 1018, 702)
# 1 itemset(s) from tree conditioned on items (309, 1018, 316)
# 3 itemset(s) from tree conditioned on items (309, 1018, 706)
# 4 itemset(s) from tree conditioned on items (309, 1018, 302)
# 0 itemset(s) from tree conditioned on items (309, 1018, 302, 316)
# 1 itemset(s) from tree conditioned on items (309, 1018, 302, 702)
# 3 itemset(s) from tree conditioned on items (309, 1018, 302, 706)
# 7 itemset(s) from tree conditioned on items (309, 1018, 302, 304)
# 7 itemset(s) from tree conditioned on items (309, 1018, 304)
# 5 itemset(s) from tree conditioned on items (309, 1018, 711)
# 0 itemset(s) from tree conditioned on items (309, 1018, 711, 702)
# 1 itemset(s) from tree conditioned on items (309, 1018, 711, 316)
# 3 itemset(s) from tree conditioned on items (309, 1018, 711, 706)
# 7 itemset(s) from tree conditioned on items (309, 1018, 711, 304)
# 1 itemset(s) from tree conditioned on items (309, 1018, 711, 302)
# 6 itemset(s) from tree conditioned on items (309, 1018, 308)
# 0 itemset(s) from tree conditioned on items (309, 1018, 308, 702)
# 1 itemset(s) from tree conditioned on items (309, 1018, 308, 316)
# 3 itemset(s) from tree conditioned on items (309, 1018, 308, 304)
# 7 itemset(s) from tree conditioned on items (309, 1018, 308, 706)
# 15 itemset(s) from tree conditioned on items (309, 1018, 308, 711)
# 1 itemset(s) from tree conditioned on items (309, 1018, 308, 302)
# 4 itemset(s) from tree conditioned on items (309, 1018, 315)
# 0 itemset(s) from tree conditioned on items (309, 1018, 315, 702)
# 1 itemset(s) from tree conditioned on items (309, 1018, 315, 711)
# 3 itemset(s) from tree conditioned on items (309, 1018, 315, 706)
# 3 itemset(s) from tree conditioned on items (309, 1018, 315, 316)
# 5 itemset(s) from tree conditioned on items (309, 307)
# 0 itemset(s) from tree conditioned on items (309, 307, 702)
# 1 itemset(s) from tree conditioned on items (309, 307, 316)
# 2 itemset(s) from tree conditioned on items (309, 307, 302)
# 0 itemset(s) from tree conditioned on items (309, 307, 302, 316)
# 1 itemset(s) from tree conditioned on items (309, 307, 302, 702)
# 3 itemset(s) from tree conditioned on items (309, 307, 706)
# 0 itemset(s) from tree conditioned on items (309, 307, 706, 702)
# 1 itemset(s) from tree conditioned on items (309, 307, 706, 316)
# 3 itemset(s) from tree conditioned on items (309, 307, 706, 302)
# 3 itemset(s) from tree conditioned on items (309, 307, 1018)
# 0 itemset(s) from tree conditioned on items (309, 307, 1018, 302)
# 0 itemset(s) from tree conditioned on items (309, 307, 1018, 316)
# 0 itemset(s) from tree conditioned on items (309, 307, 1018, 702)
# 4 itemset(s) from tree conditioned on items (309, 700)
# 0 itemset(s) from tree conditioned on items (309, 700, 702)
# 1 itemset(s) from tree conditioned on items (309, 700, 316)
# 3 itemset(s) from tree conditioned on items (309, 700, 706)
# 7 itemset(s) from tree conditioned on items (309, 700, 304)
# 6 itemset(s) from tree conditioned on items (309, 712)
# 0 itemset(s) from tree conditioned on items (309, 712, 702)
# 0 itemset(s) from tree conditioned on items (309, 712, 308)
# 1 itemset(s) from tree conditioned on items (309, 712, 316)
# 3 itemset(s) from tree conditioned on items (309, 712, 302)
# 7 itemset(s) from tree conditioned on items (309, 712, 718)
# 15 itemset(s) from tree conditioned on items (309, 712, 714)
# 11 itemset(s) from tree conditioned on items (309, 317)
# 0 itemset(s) from tree conditioned on items (309, 317, 702)
# 2 itemset(s) from tree conditioned on items (309, 317, 316)
# 1 itemset(s) from tree conditioned on items (309, 317, 316, 702)
# 0 itemset(s) from tree conditioned on items (309, 317, 316, 1018)
# 0 itemset(s) from tree conditioned on items (309, 317, 307)
# 1 itemset(s) from tree conditioned on items (309, 317, 1018)
# 3 itemset(s) from tree conditioned on items (309, 317, 302)
# 0 itemset(s) from tree conditioned on items (309, 317, 302, 1018)
# 0 itemset(s) from tree conditioned on items (309, 317, 302, 702)
# 0 itemset(s) from tree conditioned on items (309, 317, 302, 316)
# 3 itemset(s) from tree conditioned on items (309, 317, 308)
# 3 itemset(s) from tree conditioned on items (309, 317, 706)
# 0 itemset(s) from tree conditioned on items (309, 317, 706, 702)
# 0 itemset(s) from tree conditioned on items (309, 317, 706, 316)
# 1 itemset(s) from tree conditioned on items (309, 317, 706, 1018)
# 3 itemset(s) from tree conditioned on items (309, 317, 710)
# 0 itemset(s) from tree conditioned on items (309, 317, 710, 706)
# 0 itemset(s) from tree conditioned on items (309, 317, 710, 1018)
# 1 itemset(s) from tree conditioned on items (309, 317, 710, 702)
# 7 itemset(s) from tree conditioned on items (309, 317, 304)
# 7 itemset(s) from tree conditioned on items (309, 317, 713)
# 1 itemset(s) from tree conditioned on items (309, 317, 711)
# 3 itemset(s) from tree conditioned on items (309, 319)
# 1 itemset(s) from tree conditioned on items (309, 319, 302)
# 0 itemset(s) from tree conditioned on items (309, 319, 308)
# 3 itemset(s) from tree conditioned on items (309, 319, 316)
# 7 itemset(s) from tree conditioned on items (309, 304)
# 4 itemset(s) from tree conditioned on items (309, 711)
# 0 itemset(s) from tree conditioned on items (309, 711, 316)
# 1 itemset(s) from tree conditioned on items (309, 711, 702)
# 2 itemset(s) from tree conditioned on items (309, 711, 706)
# 0 itemset(s) from tree conditioned on items (309, 711, 706, 702)
# 1 itemset(s) from tree conditioned on items (309, 711, 706, 316)
# 7 itemset(s) from tree conditioned on items (309, 711, 304)
# 6 itemset(s) from tree conditioned on items (309, 308)
# 0 itemset(s) from tree conditioned on items (309, 308, 316)
# 1 itemset(s) from tree conditioned on items (309, 308, 702)
# 3 itemset(s) from tree conditioned on items (309, 308, 706)
# 7 itemset(s) from tree conditioned on items (309, 308, 304)
# 15 itemset(s) from tree conditioned on items (309, 308, 711)
# 3 itemset(s) from tree conditioned on items (309, 308, 302)
# 0 itemset(s) from tree conditioned on items (309, 308, 302, 316)
# 1 itemset(s) from tree conditioned on items (309, 308, 302, 702)
# 1 itemset(s) from tree conditioned on items (309, 308, 302, 711)
# 9 itemset(s) from tree conditioned on items (309, 710)
# 0 itemset(s) from tree conditioned on items (309, 710, 702)
# 1 itemset(s) from tree conditioned on items (309, 710, 706)
# 3 itemset(s) from tree conditioned on items (309, 710, 304)
# 3 itemset(s) from tree conditioned on items (309, 710, 316)
# 0 itemset(s) from tree conditioned on items (309, 710, 316, 702)
# 1 itemset(s) from tree conditioned on items (309, 710, 316, 706)
# 3 itemset(s) from tree conditioned on items (309, 710, 316, 304)
# 4 itemset(s) from tree conditioned on items (309, 710, 711)
# 0 itemset(s) from tree conditioned on items (309, 710, 711, 316)
# 1 itemset(s) from tree conditioned on items (309, 710, 711, 706)
# 2 itemset(s) from tree conditioned on items (309, 710, 711, 702)
# 0 itemset(s) from tree conditioned on items (309, 710, 711, 702, 706)
# 1 itemset(s) from tree conditioned on items (309, 710, 711, 702, 316)
# 7 itemset(s) from tree conditioned on items (309, 710, 711, 304)
# 5 itemset(s) from tree conditioned on items (309, 710, 1018)
# 0 itemset(s) from tree conditioned on items (309, 710, 1018, 702)
# 1 itemset(s) from tree conditioned on items (309, 710, 1018, 304)
# 3 itemset(s) from tree conditioned on items (309, 710, 1018, 706)
# 7 itemset(s) from tree conditioned on items (309, 710, 1018, 316)
# 15 itemset(s) from tree conditioned on items (309, 710, 1018, 711)
# 6 itemset(s) from tree conditioned on items (309, 710, 308)
# 0 itemset(s) from tree conditioned on items (309, 710, 308, 702)
# 1 itemset(s) from tree conditioned on items (309, 710, 308, 316)
# 3 itemset(s) from tree conditioned on items (309, 710, 308, 304)
# 7 itemset(s) from tree conditioned on items (309, 710, 308, 706)
# 15 itemset(s) from tree conditioned on items (309, 710, 308, 711)
# 1 itemset(s) from tree conditioned on items (309, 710, 308, 1018)
# 4 itemset(s) from tree conditioned on items (309, 710, 302)
# 0 itemset(s) from tree conditioned on items (309, 710, 302, 702)
# 1 itemset(s) from tree conditioned on items (309, 710, 302, 316)
# 2 itemset(s) from tree conditioned on items (309, 710, 302, 706)
# 0 itemset(s) from tree conditioned on items (309, 710, 302, 706, 316)
# 0 itemset(s) from tree conditioned on items (309, 710, 302, 706, 702)
# 3 itemset(s) from tree conditioned on items (309, 710, 302, 304)
# 5 itemset(s) from tree conditioned on items (309, 710, 315)
# 0 itemset(s) from tree conditioned on items (309, 710, 315, 706)
# 1 itemset(s) from tree conditioned on items (309, 710, 315, 702)
# 3 itemset(s) from tree conditioned on items (309, 710, 315, 304)
# 7 itemset(s) from tree conditioned on items (309, 710, 315, 316)
# 15 itemset(s) from tree conditioned on items (309, 710, 315, 711)
# 10 itemset(s) from tree conditioned on items (309, 713)
# 0 itemset(s) from tree conditioned on items (309, 713, 702)
# 1 itemset(s) from tree conditioned on items (309, 713, 304)
# 3 itemset(s) from tree conditioned on items (309, 713, 706)
# 7 itemset(s) from tree conditioned on items (309, 713, 316)
# 15 itemset(s) from tree conditioned on items (309, 713, 711)
# 5 itemset(s) from tree conditioned on items (309, 713, 308)
# 0 itemset(s) from tree conditioned on items (309, 713, 308, 702)
# 1 itemset(s) from tree conditioned on items (309, 713, 308, 706)
# 3 itemset(s) from tree conditioned on items (309, 713, 308, 304)
# 7 itemset(s) from tree conditioned on items (309, 713, 308, 316)
# 15 itemset(s) from tree conditioned on items (309, 713, 308, 711)
# 7 itemset(s) from tree conditioned on items (309, 713, 710)
# 0 itemset(s) from tree conditioned on items (309, 713, 710, 702)
# 1 itemset(s) from tree conditioned on items (309, 713, 710, 706)
# 3 itemset(s) from tree conditioned on items (309, 713, 710, 304)
# 7 itemset(s) from tree conditioned on items (309, 713, 710, 316)
# 15 itemset(s) from tree conditioned on items (309, 713, 710, 711)
# 31 itemset(s) from tree conditioned on items (309, 713, 710, 308)
# 31 itemset(s) from tree conditioned on items (309, 713, 710, 315)
# 7 itemset(s) from tree conditioned on items (309, 713, 1018)
# 0 itemset(s) from tree conditioned on items (309, 713, 1018, 702)
# 1 itemset(s) from tree conditioned on items (309, 713, 1018, 308)
# 3 itemset(s) from tree conditioned on items (309, 713, 1018, 706)
# 7 itemset(s) from tree conditioned on items (309, 713, 1018, 304)
# 4 itemset(s) from tree conditioned on items (309, 713, 1018, 316)
# 0 itemset(s) from tree conditioned on items (309, 713, 1018, 316, 702)
# 1 itemset(s) from tree conditioned on items (309, 713, 1018, 316, 304)
# 3 itemset(s) from tree conditioned on items (309, 713, 1018, 316, 706)
# 7 itemset(s) from tree conditioned on items (309, 713, 1018, 316, 308)
# 31 itemset(s) from tree conditioned on items (309, 713, 1018, 711)
# 15 itemset(s) from tree conditioned on items (309, 713, 1018, 710)
# 15 itemset(s) from tree conditioned on items (309, 713, 302)
# 6 itemset(s) from tree conditioned on items (309, 713, 315)
# 0 itemset(s) from tree conditioned on items (309, 713, 315, 316)
# 1 itemset(s) from tree conditioned on items (309, 713, 315, 706)
# 3 itemset(s) from tree conditioned on items (309, 713, 315, 304)
# 7 itemset(s) from tree conditioned on items (309, 713, 315, 702)
# 15 itemset(s) from tree conditioned on items (309, 713, 315, 711)
# 31 itemset(s) from tree conditioned on items (309, 713, 315, 308)
# 11 itemset(s) from tree conditioned on items (309, 312)
# 0 itemset(s) from tree conditioned on items (309, 312, 702)
# 1 itemset(s) from tree conditioned on items (309, 312, 316)
# 3 itemset(s) from tree conditioned on items (309, 312, 308)
# 3 itemset(s) from tree conditioned on items (309, 312, 706)
# 0 itemset(s) from tree conditioned on items (309, 312, 706, 702)
# 1 itemset(s) from tree conditioned on items (309, 312, 706, 316)
# 3 itemset(s) from tree conditioned on items (309, 312, 706, 308)
# 4 itemset(s) from tree conditioned on items (309, 312, 304)
# 0 itemset(s) from tree conditioned on items (309, 312, 304, 706)
# 1 itemset(s) from tree conditioned on items (309, 312, 304, 702)
# 3 itemset(s) from tree conditioned on items (309, 312, 304, 316)
# 7 itemset(s) from tree conditioned on items (309, 312, 304, 308)
# 5 itemset(s) from tree conditioned on items (309, 312, 713)
# 0 itemset(s) from tree conditioned on items (309, 312, 713, 702)
# 1 itemset(s) from tree conditioned on items (309, 312, 713, 304)
# 3 itemset(s) from tree conditioned on items (309, 312, 713, 706)
# 7 itemset(s) from tree conditioned on items (309, 312, 713, 308)
# 4 itemset(s) from tree conditioned on items (309, 312, 713, 316)
# 0 itemset(s) from tree conditioned on items (309, 312, 713, 316, 702)
# 1 itemset(s) from tree conditioned on items (309, 312, 713, 316, 706)
# 3 itemset(s) from tree conditioned on items (309, 312, 713, 316, 304)
# 7 itemset(s) from tree conditioned on items (309, 312, 713, 316, 308)
# 63 itemset(s) from tree conditioned on items (309, 312, 711)
# 5 itemset(s) from tree conditioned on items (309, 312, 710)
# 0 itemset(s) from tree conditioned on items (309, 312, 710, 702)
# 1 itemset(s) from tree conditioned on items (309, 312, 710, 304)
# 3 itemset(s) from tree conditioned on items (309, 312, 710, 706)
# 1 itemset(s) from tree conditioned on items (309, 312, 710, 308)
# 7 itemset(s) from tree conditioned on items (309, 312, 710, 316)
# 7 itemset(s) from tree conditioned on items (309, 312, 1018)
# 7 itemset(s) from tree conditioned on items (309, 312, 1017)
# 0 itemset(s) from tree conditioned on items (309, 312, 1017, 713)
# 1 itemset(s) from tree conditioned on items (309, 312, 1017, 304)
# 3 itemset(s) from tree conditioned on items (309, 312, 1017, 706)
# 7 itemset(s) from tree conditioned on items (309, 312, 1017, 702)
# 15 itemset(s) from tree conditioned on items (309, 312, 1017, 711)
# 31 itemset(s) from tree conditioned on items (309, 312, 1017, 308)
# 63 itemset(s) from tree conditioned on items (309, 312, 1017, 316)
# 6 itemset(s) from tree conditioned on items (309, 312, 315)
# 0 itemset(s) from tree conditioned on items (309, 312, 315, 702)
# 1 itemset(s) from tree conditioned on items (309, 312, 315, 316)
# 3 itemset(s) from tree conditioned on items (309, 312, 315, 706)
# 7 itemset(s) from tree conditioned on items (309, 312, 315, 304)
# 15 itemset(s) from tree conditioned on items (309, 312, 315, 713)
# 3 itemset(s) from tree conditioned on items (309, 312, 315, 308)
# 10 itemset(s) from tree conditioned on items (309, 301)
# 0 itemset(s) from tree conditioned on items (309, 301, 702)
# 1 itemset(s) from tree conditioned on items (309, 301, 304)
# 3 itemset(s) from tree conditioned on items (309, 301, 706)
# 7 itemset(s) from tree conditioned on items (309, 301, 316)
# 15 itemset(s) from tree conditioned on items (309, 301, 710)
# 31 itemset(s) from tree conditioned on items (309, 301, 713)
# 63 itemset(s) from tree conditioned on items (309, 301, 711)
# 6 itemset(s) from tree conditioned on items (309, 301, 1018)
# 0 itemset(s) from tree conditioned on items (309, 301, 1018, 706)
# 1 itemset(s) from tree conditioned on items (309, 301, 1018, 304)
# 3 itemset(s) from tree conditioned on items (309, 301, 1018, 702)
# ...
# 0 itemset(s) from tree conditioned on items (300, 709, 702, 316)
# 1 itemset(s) from tree conditioned on items (300, 709, 702, 302)
# 3 itemset(s) from tree conditioned on items (300, 709, 711)
# 0 itemset(s) from tree conditioned on items (300, 709, 711, 316)
# 2 itemset(s) from tree conditioned on items (300, 709, 711, 702)
# 0 itemset(s) from tree conditioned on items (300, 709, 711, 702, 316)
# 1 itemset(s) from tree conditioned on items (300, 709, 711, 702, 302)
# 1 itemset(s) from tree conditioned on items (300, 709, 711, 302)
# 1 itemset(s) from tree conditioned on items (300, 709, 302)
# 3 itemset(s) from tree conditioned on items (300, 709, 714)
# 0 itemset(s) from tree conditioned on items (300, 709, 714, 302)
# 1 itemset(s) from tree conditioned on items (300, 709, 714, 316)
# 3 itemset(s) from tree conditioned on items (300, 709, 714, 702)
# 7 itemset(s) from tree conditioned on items (300, 709, 308)
# 5 itemset(s) from tree conditioned on items (300, 706)
# 0 itemset(s) from tree conditioned on items (300, 706, 702)
# 1 itemset(s) from tree conditioned on items (300, 706, 316)
# 3 itemset(s) from tree conditioned on items (300, 706, 304)
# 3 itemset(s) from tree conditioned on items (300, 706, 711)
# 0 itemset(s) from tree conditioned on items (300, 706, 711, 316)
# 1 itemset(s) from tree conditioned on items (300, 706, 711, 702)
# 3 itemset(s) from tree conditioned on items (300, 706, 711, 304)
# 1 itemset(s) from tree conditioned on items (300, 706, 308)
# 4 itemset(s) from tree conditioned on items (300, 713)
# 0 itemset(s) from tree conditioned on items (300, 713, 702)
# 1 itemset(s) from tree conditioned on items (300, 713, 316)
# 3 itemset(s) from tree conditioned on items (300, 713, 706)
# 3 itemset(s) from tree conditioned on items (300, 713, 711)
# 4 itemset(s) from tree conditioned on items (300, 710)
# 0 itemset(s) from tree conditioned on items (300, 710, 702)
# 1 itemset(s) from tree conditioned on items (300, 710, 316)
# 3 itemset(s) from tree conditioned on items (300, 710, 706)
# 7 itemset(s) from tree conditioned on items (300, 710, 304)
# 1 itemset(s) from tree conditioned on items (300, 305)
# 3 itemset(s) from tree conditioned on items (300, 717)
# 0 itemset(s) from tree conditioned on items (300, 717, 702)
# 1 itemset(s) from tree conditioned on items (300, 717, 304)
# 1 itemset(s) from tree conditioned on items (300, 717, 316)
# 8 itemset(s) from tree conditioned on items (300, 301)
# 1 itemset(s) from tree conditioned on items (300, 301, 302)
# 2 itemset(s) from tree conditioned on items (300, 301, 316)
# 1 itemset(s) from tree conditioned on items (300, 301, 316, 302)
# 0 itemset(s) from tree conditioned on items (300, 301, 316, 702)
# 3 itemset(s) from tree conditioned on items (300, 301, 709)
# 0 itemset(s) from tree conditioned on items (300, 301, 709, 302)
# 3 itemset(s) from tree conditioned on items (300, 301, 709, 316)
# 1 itemset(s) from tree conditioned on items (300, 301, 709, 702)
# 0 itemset(s) from tree conditioned on items (300, 301, 702)
# 15 itemset(s) from tree conditioned on items (300, 301, 711)
# 15 itemset(s) from tree conditioned on items (300, 301, 308)
# 1 itemset(s) from tree conditioned on items (300, 301, 1018)
# 4 itemset(s) from tree conditioned on items (300, 301, 714)
# 0 itemset(s) from tree conditioned on items (300, 301, 714, 302)
# 1 itemset(s) from tree conditioned on items (300, 301, 714, 702)
# 3 itemset(s) from tree conditioned on items (300, 301, 714, 709)
# 7 itemset(s) from tree conditioned on items (300, 301, 714, 316)
# 4 itemset(s) from tree conditioned on items (300, 317)
# 0 itemset(s) from tree conditioned on items (300, 317, 302)
# 0 itemset(s) from tree conditioned on items (300, 317, 316)
# 1 itemset(s) from tree conditioned on items (300, 317, 702)
# 0 itemset(s) from tree conditioned on items (300, 317, 1018)
# 7 itemset(s) from tree conditioned on items (300, 1017)
# 0 itemset(s) from tree conditioned on items (300, 1017, 302)
# 1 itemset(s) from tree conditioned on items (300, 1017, 316)
# 3 itemset(s) from tree conditioned on items (300, 1017, 714)
# 1 itemset(s) from tree conditioned on items (300, 1017, 711)
# 2 itemset(s) from tree conditioned on items (300, 1017, 702)
# 1 itemset(s) from tree conditioned on items (300, 1017, 702, 316)
# 0 itemset(s) from tree conditioned on items (300, 1017, 702, 302)
# 0 itemset(s) from tree conditioned on items (300, 1017, 308)
# 2 itemset(s) from tree conditioned on items (300, 1017, 1018)
# 0 itemset(s) from tree conditioned on items (300, 1017, 1018, 302)
# 0 itemset(s) from tree conditioned on items (300, 1017, 1018, 702)
# 4 itemset(s) from tree conditioned on items (300, 703)
# 0 itemset(s) from tree conditioned on items (300, 703, 702)
# 1 itemset(s) from tree conditioned on items (300, 703, 717)
# 3 itemset(s) from tree conditioned on items (300, 703, 304)
# 1 itemset(s) from tree conditioned on items (300, 703, 316)
# 2 itemset(s) from tree conditioned on items (300, 312)
# 0 itemset(s) from tree conditioned on items (300, 312, 316)
# 0 itemset(s) from tree conditioned on items (300, 312, 702)
# 0 itemset(s) from tree conditioned on items (300, 314)
# 4 itemset(s) from tree conditioned on items (300, 1018)
# 0 itemset(s) from tree conditioned on items (300, 1018, 302)
# 1 itemset(s) from tree conditioned on items (300, 1018, 316)
# 3 itemset(s) from tree conditioned on items (300, 1018, 711)
# 0 itemset(s) from tree conditioned on items (300, 1018, 711, 302)
# 2 itemset(s) from tree conditioned on items (300, 1018, 711, 316)
# 0 itemset(s) from tree conditioned on items (300, 1018, 711, 316, 302)
# 0 itemset(s) from tree conditioned on items (300, 1018, 711, 316, 702)
# 1 itemset(s) from tree conditioned on items (300, 1018, 711, 702)
# 2 itemset(s) from tree conditioned on items (300, 1018, 702)
# 1 itemset(s) from tree conditioned on items (300, 1018, 702, 316)
# 0 itemset(s) from tree conditioned on items (300, 1018, 702, 302)
# 6 itemset(s) from tree conditioned on items (300, 308)
# 1 itemset(s) from tree conditioned on items (300, 308, 302)
# 2 itemset(s) from tree conditioned on items (300, 308, 316)
# 1 itemset(s) from tree conditioned on items (300, 308, 316, 302)
# 0 itemset(s) from tree conditioned on items (300, 308, 316, 702)
# 3 itemset(s) from tree conditioned on items (300, 308, 711)
# 1 itemset(s) from tree conditioned on items (300, 308, 711, 302)
# 1 itemset(s) from tree conditioned on items (300, 308, 711, 316)
# 0 itemset(s) from tree conditioned on items (300, 308, 711, 702)
# 3 itemset(s) from tree conditioned on items (300, 308, 1018)
# 0 itemset(s) from tree conditioned on items (300, 308, 1018, 302)
# 1 itemset(s) from tree conditioned on items (300, 308, 1018, 316)
# 1 itemset(s) from tree conditioned on items (300, 308, 1018, 702)
# 3 itemset(s) from tree conditioned on items (300, 308, 714)
# 0 itemset(s) from tree conditioned on items (300, 308, 714, 316)
# 1 itemset(s) from tree conditioned on items (300, 308, 714, 302)
# 3 itemset(s) from tree conditioned on items (300, 308, 714, 702)
# 0 itemset(s) from tree conditioned on items (300, 308, 702)
# 9 itemset(s) from tree conditioned on items (300, 319)
# 0 itemset(s) from tree conditioned on items (300, 319, 302)
# 1 itemset(s) from tree conditioned on items (300, 319, 316)
# 3 itemset(s) from tree conditioned on items (300, 319, 1018)
# 0 itemset(s) from tree conditioned on items (300, 319, 1018, 302)
# 1 itemset(s) from tree conditioned on items (300, 319, 1018, 316)
# 1 itemset(s) from tree conditioned on items (300, 319, 1018, 702)
# 2 itemset(s) from tree conditioned on items (300, 319, 711)
# 0 itemset(s) from tree conditioned on items (300, 319, 711, 302)
# 0 itemset(s) from tree conditioned on items (300, 319, 711, 316)
# 3 itemset(s) from tree conditioned on items (300, 319, 308)
# 0 itemset(s) from tree conditioned on items (300, 319, 308, 302)
# 3 itemset(s) from tree conditioned on items (300, 319, 308, 1018)
# 1 itemset(s) from tree conditioned on items (300, 319, 308, 702)
# 3 itemset(s) from tree conditioned on items (300, 319, 714)
# 3 itemset(s) from tree conditioned on items (300, 319, 709)
# 3 itemset(s) from tree conditioned on items (300, 319, 307)
# 1 itemset(s) from tree conditioned on items (300, 319, 702)
# 6 itemset(s) from tree conditioned on items (300, 705)
# 0 itemset(s) from tree conditioned on items (300, 705, 711)
# 1 itemset(s) from tree conditioned on items (300, 705, 302)
# 2 itemset(s) from tree conditioned on items (300, 705, 316)
# 0 itemset(s) from tree conditioned on items (300, 705, 316, 302)
# 0 itemset(s) from tree conditioned on items (300, 705, 316, 711)
# 1 itemset(s) from tree conditioned on items (300, 705, 1018)
# 3 itemset(s) from tree conditioned on items (300, 705, 308)
# 3 itemset(s) from tree conditioned on items (300, 705, 702)
# 6 itemset(s) from tree conditioned on items (300, 307)
# 1 itemset(s) from tree conditioned on items (300, 307, 316)
# 3 itemset(s) from tree conditioned on items (300, 307, 302)
# 0 itemset(s) from tree conditioned on items (300, 307, 702)
# 3 itemset(s) from tree conditioned on items (300, 307, 1018)
# 1 itemset(s) from tree conditioned on items (300, 307, 1018, 702)
# 0 itemset(s) from tree conditioned on items (300, 307, 1018, 316)
# 1 itemset(s) from tree conditioned on items (300, 307, 1018, 302)
# 3 itemset(s) from tree conditioned on items (300, 307, 308)
# 0 itemset(s) from tree conditioned on items (300, 307, 308, 702)
# 0 itemset(s) from tree conditioned on items (300, 307, 308, 302)
# 0 itemset(s) from tree conditioned on items (300, 307, 308, 316)
# 1 itemset(s) from tree conditioned on items (300, 307, 714)
# 1 itemset(s) from tree conditioned on items (300, 718)
# 3 itemset(s) from tree conditioned on items (300, 704)
# 0 itemset(s) from tree conditioned on items (300, 704, 711)
# 1 itemset(s) from tree conditioned on items (300, 704, 316)
# 1 itemset(s) from tree conditioned on items (300, 704, 702)
# 0 itemset(s) from tree conditioned on items (300, 306)
# 24 itemset(s) from tree conditioned on items (708)
# 0 itemset(s) from tree conditioned on items (708, 702)
# 2 itemset(s) from tree conditioned on items (708, 307)
# 0 itemset(s) from tree conditioned on items (708, 307, 702)
# 1 itemset(s) from tree conditioned on items (708, 307, 316)
# 3 itemset(s) from tree conditioned on items (708, 302)
# 0 itemset(s) from tree conditioned on items (708, 302, 702)
# 1 itemset(s) from tree conditioned on items (708, 302, 316)
# 2 itemset(s) from tree conditioned on items (708, 302, 307)
# 0 itemset(s) from tree conditioned on items (708, 302, 307, 702)
# 1 itemset(s) from tree conditioned on items (708, 302, 307, 316)
# 5 itemset(s) from tree conditioned on items (708, 319)
# 0 itemset(s) from tree conditioned on items (708, 319, 302)
# 0 itemset(s) from tree conditioned on items (708, 319, 711)
# 1 itemset(s) from tree conditioned on items (708, 319, 702)
# 3 itemset(s) from tree conditioned on items (708, 319, 316)
# 3 itemset(s) from tree conditioned on items (708, 319, 307)
# 1 itemset(s) from tree conditioned on items (708, 316)
# 4 itemset(s) from tree conditioned on items (708, 711)
# 0 itemset(s) from tree conditioned on items (708, 711, 702)
# 1 itemset(s) from tree conditioned on items (708, 711, 316)
# 2 itemset(s) from tree conditioned on items (708, 711, 302)
# 0 itemset(s) from tree conditioned on items (708, 711, 302, 316)
# 1 itemset(s) from tree conditioned on items (708, 711, 302, 702)
# 2 itemset(s) from tree conditioned on items (708, 711, 307)
# 0 itemset(s) from tree conditioned on items (708, 711, 307, 702)
# 1 itemset(s) from tree conditioned on items (708, 711, 307, 316)
# 5 itemset(s) from tree conditioned on items (708, 1018)
# 0 itemset(s) from tree conditioned on items (708, 1018, 702)
# 1 itemset(s) from tree conditioned on items (708, 1018, 316)
# 1 itemset(s) from tree conditioned on items (708, 1018, 302)
# 1 itemset(s) from tree conditioned on items (708, 1018, 307)
# 1 itemset(s) from tree conditioned on items (708, 1018, 711)
# 4 itemset(s) from tree conditioned on items (708, 706)
# 0 itemset(s) from tree conditioned on items (708, 706, 702)
# 1 itemset(s) from tree conditioned on items (708, 706, 307)
# 3 itemset(s) from tree conditioned on items (708, 706, 302)
# 3 itemset(s) from tree conditioned on items (708, 706, 316)
# 6 itemset(s) from tree conditioned on items (708, 301)
# 0 itemset(s) from tree conditioned on items (708, 301, 702)
# 1 itemset(s) from tree conditioned on items (708, 301, 316)
# 3 itemset(s) from tree conditioned on items (708, 301, 302)
# 1 itemset(s) from tree conditioned on items (708, 301, 706)
# 1 itemset(s) from tree conditioned on items (708, 301, 711)
# 0 itemset(s) from tree conditioned on items (708, 301, 307)
# 7 itemset(s) from tree conditioned on items (708, 1017)
# 0 itemset(s) from tree conditioned on items (708, 1017, 702)
# 0 itemset(s) from tree conditioned on items (708, 1017, 307)
# 1 itemset(s) from tree conditioned on items (708, 1017, 706)
# 0 itemset(s) from tree conditioned on items (708, 1017, 302)
# 0 itemset(s) from tree conditioned on items (708, 1017, 316)
# 0 itemset(s) from tree conditioned on items (708, 1017, 301)
# 0 itemset(s) from tree conditioned on items (708, 1017, 1018)
# 6 itemset(s) from tree conditioned on items (708, 710)
# 0 itemset(s) from tree conditioned on items (708, 710, 702)
# 1 itemset(s) from tree conditioned on items (708, 710, 706)
# 3 itemset(s) from tree conditioned on items (708, 710, 302)
# 3 itemset(s) from tree conditioned on items (708, 710, 307)
# 3 itemset(s) from tree conditioned on items (708, 710, 1017)
# 3 itemset(s) from tree conditioned on items (708, 710, 301)
# 4 itemset(s) from tree conditioned on items (708, 304)
# 0 itemset(s) from tree conditioned on items (708, 304, 702)
# 1 itemset(s) from tree conditioned on items (708, 304, 706)
# 1 itemset(s) from tree conditioned on items (708, 304, 316)
# 0 itemset(s) from tree conditioned on items (708, 304, 307)
# 0 itemset(s) from tree conditioned on items (708, 308)
# 0 itemset(s) from tree conditioned on items (708, 713)
# 1 itemset(s) from tree conditioned on items (708, 305)
# 1 itemset(s) from tree conditioned on items (708, 311)
# 1 itemset(s) from tree conditioned on items (708, 1021)
# 4 itemset(s) from tree conditioned on items (708, 705)
# 0 itemset(s) from tree conditioned on items (708, 705, 711)
# 1 itemset(s) from tree conditioned on items (708, 705, 702)
# 3 itemset(s) from tree conditioned on items (708, 705, 302)
# 2 itemset(s) from tree conditioned on items (708, 705, 712)
# 0 itemset(s) from tree conditioned on items (708, 705, 712, 711)
# 1 itemset(s) from tree conditioned on items (708, 705, 712, 702)
# 3 itemset(s) from tree conditioned on items (708, 704)
# 0 itemset(s) from tree conditioned on items (708, 704, 702)
# 1 itemset(s) from tree conditioned on items (708, 704, 302)
# 3 itemset(s) from tree conditioned on items (708, 704, 307)
# 4 itemset(s) from tree conditioned on items (708, 714)
# 0 itemset(s) from tree conditioned on items (708, 714, 316)
# 1 itemset(s) from tree conditioned on items (708, 714, 702)
# 0 itemset(s) from tree conditioned on items (708, 714, 302)
# 1 itemset(s) from tree conditioned on items (708, 714, 307)
# 1 itemset(s) from tree conditioned on items (708, 715)
# 4 itemset(s) from tree conditioned on items (708, 712)
# 0 itemset(s) from tree conditioned on items (708, 712, 711)
# 1 itemset(s) from tree conditioned on items (708, 712, 302)
# 1 itemset(s) from tree conditioned on items (708, 712, 702)
# 2 itemset(s) from tree conditioned on items (708, 712, 316)
# 0 itemset(s) from tree conditioned on items (708, 712, 316, 302)
# 0 itemset(s) from tree conditioned on items (708, 712, 316, 711)
# 5 itemset(s) from tree conditioned on items (708, 709)
# 0 itemset(s) from tree conditioned on items (708, 709, 702)
# 1 itemset(s) from tree conditioned on items (708, 709, 712)
# 1 itemset(s) from tree conditioned on items (708, 709, 301)
# 1 itemset(s) from tree conditioned on items (708, 709, 711)
# 1 itemset(s) from tree conditioned on items (708, 709, 316)
# 3 itemset(s) from tree conditioned on items (708, 303)
# 0 itemset(s) from tree conditioned on items (708, 303, 307)
# 1 itemset(s) from tree conditioned on items (708, 303, 702)
# 3 itemset(s) from tree conditioned on items (708, 303, 316)
# 51681 patterns

# %%
MIN_CONF: float = 0.2
rules = {}
for name, p in patterns.items():
    print("-------------{}-------------".format(name))
    rules[name] = g20PM.get_rules(p, MIN_CONF)
# Out:
# -------------Original-------------
# 	found 559847 rules

# %% [markdown]
# Quality evaluation per support

# %%
for name, r in rules.items():
    print("-------------{}-------------".format(name))
    nr_rules_sp = g20PM.analyse_per_metric(r, 'support', var_min_sup)
    ds.plot_line(var_min_sup, nr_rules_sp, title='Nr rules x Support', xlabel='support',
                 ylabel='Nr. rules', percentage=False)
# Out:
# -------------Original-------------
# Analyse per support...

# %% [markdown]
# Quality evaluation per confidence

# %%
var_min_conf = [i * MIN_CONF for i in range(10, 0, -1)]
for name, r in rules.items():
    print("-------------{}-------------".format(name))
    nr_rules_cf = g20PM.analyse_per_metric(r, 'confidence', var_min_conf)
    ds.plot_line(var_min_conf, nr_rules_cf, title='Nr Rules x Confidence', xlabel='confidence', ylabel='Nr Rules', percentage=False)
# Out:
# -------------Original-------------
# Analyse per confidence...
