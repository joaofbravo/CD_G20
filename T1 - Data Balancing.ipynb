# %%
import numpy as np
import pandas as pd
import g20_functions as g20

values = g20.balanceData(g20.loadToxic(), dataset='Toxic')
# Out:
# Minority class: 741
# Majority class: 8251
# Proportion: 0.09 : 1

# %%
import g20_KNN
for k, v in values.items():
    X, y, labels = g20.xySplit(v, target=1024)
    g20_KNN.holdoutKNN(X, y, labels, "Toxic_"+k)
# Out:
# -> Holdout for Toxic_Original:
# Best results: 5 neighbors, manhattan metric, 0.94 accuracy
# -> Holdout for Toxic_UnderSample:
# Best results: 5 neighbors, manhattan metric, 0.80 accuracy
# -> Holdout for Toxic_OverSample:
# Best results: 1 neighbors, manhattan metric, 0.97 accuracy
# -> Holdout for Toxic_SMOTE:
# Best results: 5 neighbors, manhattan metric, 0.94 accuracy

# %%
from g20_Naive_Bayes import holdoutNaiveBayes
for k, v in values.items():
    X, y, labels = g20.xySplit(v, target=1024)
    holdoutNaiveBayes(X, y, labels, "Toxic_"+k)
# Out:
# -> Holdout for Toxic_Original:
# Holdout score for Toxic_Original: [0.78 0.84 0.8 ]
# -> Holdout for Toxic_UnderSample:
# Holdout score for Toxic_UnderSample: [0.72 0.77 0.72]
# -> Holdout for Toxic_OverSample:
# Holdout score for Toxic_OverSample: [0.75 0.75 0.71]
# -> Holdout for Toxic_SMOTE:
# Holdout score for Toxic_SMOTE: [0.78 0.84 0.8 ]

# %%
from g20_Decision_Trees import holdoutDT
for k, v in values.items():
    X, y, labels = g20.xySplit(v, target=1024)
    holdoutDT(X, y, labels, "Toxic_"+k)
# Out:
# -> Holdout for Toxic_Original:
# Best results achieved with entropy criteria, depth=5 and min_impurity_decrease=0.00 ==> accuracy=0.93
# -> Holdout for Toxic_UnderSample:
# Best results achieved with gini criteria, depth=10 and min_impurity_decrease=0.00 ==> accuracy=0.77
# -> Holdout for Toxic_OverSample:
# Best results achieved with entropy criteria, depth=25 and min_impurity_decrease=0.00 ==> accuracy=0.92
# -> Holdout for Toxic_SMOTE:
# Best results achieved with entropy criteria, depth=5 and min_impurity_decrease=0.00 ==> accuracy=0.93

# %%
from g20_Random_Forests import holdoutRF
for k, v in values.items():
    X, y, labels = g20.xySplit(v, target=1024)
    holdoutRF(X, y, labels, "Toxic_"+k)
# Out:
# -> Holdout for Toxic_Original:
# Best results with depth=25, 0.50 features, gini criterion  and 10 estimators, with accuracy=0.94
# -> Holdout for Toxic_UnderSample:
# Best results with depth=25, 0.10 features, gini criterion  and 150 estimators, with accuracy=0.85
# -> Holdout for Toxic_OverSample:
# Best results with depth=25, 0.10 features, entropy criterion  and 10 estimators, with accuracy=0.98
# -> Holdout for Toxic_SMOTE:
# Best results with depth=25, 0.50 features, gini criterion  and 10 estimators, with accuracy=0.94

# %%
from g20_Gradient_Boosting import holdoutGB
for k, v in values.items():
    X, y, labels = g20.xySplit(v, target=1024)
    holdoutGB(X, y, labels, "Toxic_"+k,
              learn_rates=[0.01, 0.1, 0.5],
              n_estimators = [100, 200, 300],
              max_depths=[5, 10, 25], max_features=[.5, 1])
# Out:
# -> Holdout for Toxic_Original:
# --- done: deviance, 5
# --- done: deviance, 10
# --- done: deviance, 25
# --- done: exponential, 5
# --- done: exponential, 10
# --- done: exponential, 25
# Best results with loss=deviance, max_depth=10, learning_rate=0.5, 300 estimators,  and 0.5 features, with accuracy=0.944
# -> Holdout for Toxic_UnderSample:
# --- done: deviance, 5
# --- done: deviance, 10
# --- done: deviance, 25
# --- done: exponential, 5
# --- done: exponential, 10
# --- done: exponential, 25
# Best results with loss=deviance, max_depth=10, learning_rate=0.1, 300 estimators,  and 0.5 features, with accuracy=0.836
# -> Holdout for Toxic_OverSample:
# --- done: deviance, 5
# --- done: deviance, 10
# --- done: deviance, 25
# --- done: exponential, 5
# --- done: exponential, 10
# --- done: exponential, 25
# Best results with loss=deviance, max_depth=25, learning_rate=0.5, 300 estimators,  and 1 features, with accuracy=0.994
# -> Holdout for Toxic_SMOTE:
# --- done: deviance, 5
# --- done: deviance, 10
# --- done: deviance, 25
# --- done: exponential, 5
# --- done: exponential, 10
# --- done: exponential, 25
# Best results with loss=deviance, max_depth=10, learning_rate=0.5, 300 estimators,  and 0.5 features, with accuracy=0.944
