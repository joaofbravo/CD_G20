# %%
import g20_functions as g20
import numpy as np
import pandas as pd
import g20_clustering

values = {"Original":g20.loadToxic()}
dataset = "Toxic"

# %%
if dataset == "Heart":
    target='DEATH_EVENT'
elif dataset == "Toxic":
    target=1024
for k,data in values.items():
    data.pop(target)

# %% [markdown]
# # K-Means

# %%
for k,data in values.items():
    print(k)
    g20_clustering.k_means(data,dataset)
# Out:
# Original
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-c504635749bb> in <module>
#       1 for k,data in values.items():
#       2     print(k)
# ----> 3     g20_clustering.k_means(data,dataset)
#
# AttributeError: module 'g20_clustering' has no attribute 'k_means'

# %% [markdown]
# # EM (Expectation-Maximization)

# %%
for k,data in values.items():
    print(k)
    g20_clustering.em(data,dataset)
# Out:
# Original
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-6d08fd623368> in <module>
#       1 for k,data in values.items():
#       2     print(k)
# ----> 3     g20_clustering.em(data,dataset)
#
# AttributeError: module 'g20_clustering' has no attribute 'em'

# %% [markdown]
# # Density-based

# %%
for k,data in values.items():
    print(k)
    g20_clustering.density(data,dataset)
# Out:
# Original
# AVG distances among records [11.441172559146954, 134.88438321707076, 0.9998726131412976, 0.7082288366972024, 0.8318665315949874]
# CHOSEN EPS [6.8647035354881725, 80, 0.5999235678847785, 0.07082288366972024, 0.12477997973924809]

# %% [markdown]
# # Hierarchical

# %%
for k,data in values.items():
    print(k)
    g20_clustering.hierarchical(data,dataset)
# Out:
# Original
