# %%
import g20_functions as g20


values = g20.balanceData(g20.loadHeart(), dataset = 'Heart')
# Out:
# Minority class: 96
# Majority class: 203
# Proportion: 0.47 : 1

# %%
from g20_KNN import crossValKNN
import numpy as np
import pandas as pd
for k,v in values.items():
    X,y,labels = g20.xySplit(v,target='DEATH_EVENT')
    crossValKNN(X,y,labels,"Heart_"+k)
# Out:
# -> 5-fold CrossVal for Heart_Original:
# Best results: 7 neighbors, chebyshev metric, 0.72 accuracy
# Best results: 17 neighbors, manhattan metric, 0.68 accuracy
# Best results: 13 neighbors, manhattan metric, 0.72 accuracy
# Best results: 3 neighbors, chebyshev metric, 0.72 accuracy
# Best results: 15 neighbors, manhattan metric, 0.68 accuracy
# Best mean results: 15 neighbors, manhattan metric, 0.68 accuracy
#
# -> 5-fold CrossVal for Heart_UnderSample:
# Best results: 19 neighbors, chebyshev metric, 0.56 accuracy
# Best results: 1 neighbors, manhattan metric, 0.69 accuracy
# Best results: 13 neighbors, manhattan metric, 0.61 accuracy
# Best results: 9 neighbors, manhattan metric, 0.66 accuracy
# Best results: 5 neighbors, manhattan metric, 0.63 accuracy
# Best mean results: 5 neighbors, manhattan metric, 0.58 accuracy
#
# -> 5-fold CrossVal for Heart_OverSample:
# Best results: 1 neighbors, chebyshev metric, 0.79 accuracy
# Best results: 1 neighbors, manhattan metric, 0.75 accuracy
# Best results: 1 neighbors, chebyshev metric, 0.74 accuracy
# Best results: 1 neighbors, manhattan metric, 0.80 accuracy
# Best results: 1 neighbors, manhattan metric, 0.78 accuracy
# Best mean results: 1 neighbors, chebyshev metric, 0.76 accuracy
#
# -> 5-fold CrossVal for Heart_SMOTE:
# Best results: 17 neighbors, manhattan metric, 0.63 accuracy
# Best results: 13 neighbors, manhattan metric, 0.68 accuracy
# Best results: 13 neighbors, manhattan metric, 0.72 accuracy
# Best results: 13 neighbors, manhattan metric, 0.68 accuracy
# Best results: 17 neighbors, manhattan metric, 0.68 accuracy
# Best mean results: 19 neighbors, manhattan metric, 0.67 accuracy

# %%
from g20_Naive_Bayes import crossValNaiveBayes
for k,v in values.items():
    X,y,labels = g20.xySplit(v,target='DEATH_EVENT')
    crossValNaiveBayes(X,y,labels,"Heart_"+k)
# Out:
# -> 5-fold CrossVal for Heart_Original:
#
# -> fold 0 for Heart_Original:
# -> fold 1 for Heart_Original:
# -> fold 2 for Heart_Original:
# -> fold 3 for Heart_Original:
# -> fold 4 for Heart_Original:
# Heart_Original
# CrossVal best estimator: GaussianNB with score 0.75
# CrossVal mean score: [0.71 0.62 0.66]
# CrossVal std: 0.0474
# -> 5-fold CrossVal for Heart_UnderSample:
#
# -> fold 0 for Heart_UnderSample:
# -> fold 1 for Heart_UnderSample:
# -> fold 2 for Heart_UnderSample:
# -> fold 3 for Heart_UnderSample:
# -> fold 4 for Heart_UnderSample:
# Heart_UnderSample
# CrossVal best estimator: GaussianNB with score 0.72
# CrossVal mean score: [0.65 0.54 0.55]
# CrossVal std: 0.0555
# -> 5-fold CrossVal for Heart_OverSample:
#
# -> fold 0 for Heart_OverSample:
# -> fold 1 for Heart_OverSample:
# -> fold 2 for Heart_OverSample:
# -> fold 3 for Heart_OverSample:
# -> fold 4 for Heart_OverSample:
# Heart_OverSample
# CrossVal best estimator: GaussianNB with score 0.69
# CrossVal mean score: [0.63 0.52 0.49]
# CrossVal std: 0.0428
# -> 5-fold CrossVal for Heart_SMOTE:
#
# -> fold 0 for Heart_SMOTE:
# -> fold 1 for Heart_SMOTE:
# -> fold 2 for Heart_SMOTE:
# -> fold 3 for Heart_SMOTE:
# -> fold 4 for Heart_SMOTE:
# Heart_SMOTE
# CrossVal best estimator: GaussianNB with score 0.80
# CrossVal mean score: [0.71 0.62 0.68]
# CrossVal std: 0.0681
