# %%
import g20_functions as g20


values = g20.balanceData(g20.loadHeart(), dataset = 'Heart')
# Out:
# Minority class: 96
# Majority class: 203
# Proportion: 0.47 : 1

# %%
from g20_KNN import crossValKNN
import numpy as np
import pandas as pd
for k,v in values.items():
    if k == 'SMOTE':
        X,y = v
        labels = pd.unique(y)
    else:
        X,y,labels = g20.xySplit(v,target='DEATH_EVENT')
    crossValKNN(X,y,labels,"Heart_"+k)
# Out:
# -> 5-fold CrossVal for Heart_Original:
# Best results: 9 neighbors, euclidean metric, 0.72 accuracy
# Best results: 15 neighbors, manhattan metric, 0.65 accuracy
# Best results: 11 neighbors, manhattan metric, 0.67 accuracy
# Best results: 13 neighbors, manhattan metric, 0.68 accuracy
# Best results: 9 neighbors, chebyshev metric, 0.69 accuracy
# Best mean results: 13 neighbors, chebyshev metric, 0.67 accuracy
#
# -> 5-fold CrossVal for Heart_UnderSample:
# Best results: 17 neighbors, manhattan metric, 0.59 accuracy
# Best results: 15 neighbors, manhattan metric, 0.62 accuracy
# Best results: 7 neighbors, chebyshev metric, 0.66 accuracy
# Best results: 5 neighbors, manhattan metric, 0.63 accuracy
# Best results: 1 neighbors, manhattan metric, 0.53 accuracy
# Best mean results: 15 neighbors, manhattan metric, 0.56 accuracy
#
# -> 5-fold CrossVal for Heart_OverSample:
# Best results: 1 neighbors, manhattan metric, 0.82 accuracy
# Best results: 1 neighbors, manhattan metric, 0.79 accuracy
# Best results: 1 neighbors, manhattan metric, 0.80 accuracy
# Best results: 1 neighbors, manhattan metric, 0.79 accuracy
# Best results: 1 neighbors, manhattan metric, 0.80 accuracy
# Best mean results: 1 neighbors, manhattan metric, 0.80 accuracy
#
# -> 5-fold CrossVal for Heart_SMOTE:
# Best results: 13 neighbors, manhattan metric, 0.70 accuracy
# Best results: 1 neighbors, manhattan metric, 0.68 accuracy
# Best results: 17 neighbors, manhattan metric, 0.67 accuracy
# Best results: 17 neighbors, manhattan metric, 0.68 accuracy
# Best results: 13 neighbors, manhattan metric, 0.69 accuracy
# Best mean results: 17 neighbors, manhattan metric, 0.68 accuracy

# %%
from g20_Naive_Bayes import crossValNaiveBayes
for k,v in values.items():
    if k == 'SMOTE':
        X,y = v
        labels = pd.unique(y)
    else:
        X,y,labels = g20.xySplit(v,target='DEATH_EVENT')
    crossValNaiveBayes(X,y,labels,"Heart_"+k)
# Out:
# -> 5-fold CrossVal for Heart_Original:
#
# -> 5-fold CrossVal for Heart_Original:
#
# -> 5-fold CrossVal for Heart_Original:
#
# -> 5-fold CrossVal for Heart_Original:
#
# -> 5-fold CrossVal for Heart_Original:
#
# -> 5-fold CrossVal for Heart_Original:
# CrossVal best estimator: GaussianNB with score 0.73
# CrossVal mean score: [0.72 0.6  0.68]
# CrossVal std: 0.0116
# -> 5-fold CrossVal for Heart_UnderSample:
#
# -> 5-fold CrossVal for Heart_UnderSample:
#
# -> 5-fold CrossVal for Heart_UnderSample:
#
# -> 5-fold CrossVal for Heart_UnderSample:
#
# -> 5-fold CrossVal for Heart_UnderSample:
#
# -> 5-fold CrossVal for Heart_UnderSample:
# CrossVal best estimator: GaussianNB with score 0.74
# CrossVal mean score: [0.62 0.54 0.45]
# CrossVal std: 0.0759
# -> 5-fold CrossVal for Heart_OverSample:
#
# -> 5-fold CrossVal for Heart_OverSample:
#
# -> 5-fold CrossVal for Heart_OverSample:
#
# -> 5-fold CrossVal for Heart_OverSample:
#
# -> 5-fold CrossVal for Heart_OverSample:
#
# -> 5-fold CrossVal for Heart_OverSample:
# CrossVal best estimator: GaussianNB with score 0.67
# CrossVal mean score: [0.64 0.53 0.51]
# CrossVal std: 0.0264
# -> 5-fold CrossVal for Heart_SMOTE:
#
# -> 5-fold CrossVal for Heart_SMOTE:
#
# -> 5-fold CrossVal for Heart_SMOTE:
#
# -> 5-fold CrossVal for Heart_SMOTE:
#
# -> 5-fold CrossVal for Heart_SMOTE:
#
# -> 5-fold CrossVal for Heart_SMOTE:
# CrossVal best estimator: GaussianNB with score 0.78
# CrossVal mean score: [0.71 0.62 0.68]
# CrossVal std: 0.0487
