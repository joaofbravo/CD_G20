# %% [markdown]
# ## Deaths

# %%
import pandas as pd
import matplotlib.pyplot as plt
import ts_functions as ts

data_d = pd.read_csv('data/deaths_pt.csv', index_col='start_date', sep=',', decimal='.',
                   parse_dates=True, dayfirst=True)
plt.figure(figsize=(3*ts.HEIGHT, ts.HEIGHT))
ts.plot_series(data_d, x_label='Date', y_label='Deaths', title='Deaths PT')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ## Covid

# %%
import pandas as pd
import matplotlib.pyplot as plt
import ts_functions as ts

data_c = pd.read_csv('data/covid19_pt.csv', index_col='Date', sep=',', decimal='.',
                   parse_dates=True, infer_datetime_format=True)
plt.figure(figsize=(3*ts.HEIGHT, ts.HEIGHT))
ts.plot_series(data_c, x_label='Date', y_label='Deaths', title='Covid PT')
plt.xticks(rotation = 45)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import ts_functions as ts

data_c2 = pd.read_csv('data/covid19_pt_2.csv', index_col='Date', sep=',', decimal='.',
                   parse_dates=True, infer_datetime_format=True)
plt.figure(figsize=(3*ts.HEIGHT, ts.HEIGHT))
ts.plot_series(data_c2, x_label='Date', y_label='Deaths', title='Covid PT')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# # Smoothing
# ## Deaths

# %%
WIN_SIZE = 4
rolling = data_d.rolling(window=WIN_SIZE)
smooth_df = rolling.mean()
plt.figure(figsize=(3*ts.HEIGHT, ts.HEIGHT/2))
ts.plot_series(smooth_df, title=f'Smoothing (win_size={WIN_SIZE})', x_label='Date', y_label='deaths')
plt.xticks(rotation = 45)
plt.show()

# %%
WIN_SIZE = 100
rolling = data_d.rolling(window=WIN_SIZE)
smooth_df = rolling.mean()
plt.figure(figsize=(3*ts.HEIGHT, ts.HEIGHT/2))
ts.plot_series(smooth_df, title=f'Smoothing (win_size={WIN_SIZE})', x_label='Date', y_label='deaths')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ## Covid

# %%
WIN_SIZE = 10
rolling = data_c.rolling(window=WIN_SIZE)
smooth_df = rolling.mean()
plt.figure(figsize=(3*ts.HEIGHT, ts.HEIGHT/2))
ts.plot_series(smooth_df, title=f'Smoothing (win_size={WIN_SIZE})', x_label='Date', y_label='deaths')
plt.xticks(rotation = 45)
plt.show()

# %%
WIN_SIZE = 100
rolling = data_c.rolling(window=WIN_SIZE)
smooth_df = rolling.mean()
plt.figure(figsize=(3*ts.HEIGHT, ts.HEIGHT/2))
ts.plot_series(smooth_df, title=f'Smoothing (win_size={WIN_SIZE})', x_label='Date', y_label='deaths')
plt.xticks(rotation = 45)
plt.show()

# %%
WIN_SIZE = 10
rolling = data_c2.rolling(window=WIN_SIZE)
smooth_df = rolling.mean()
plt.figure(figsize=(3*ts.HEIGHT, ts.HEIGHT/2))
ts.plot_series(smooth_df, title=f'Smoothing (win_size={WIN_SIZE})', x_label='Date', y_label='deaths')
plt.xticks(rotation = 45)
plt.show()

# %%
WIN_SIZE = 100
rolling = data_c2.rolling(window=WIN_SIZE)
smooth_df = rolling.mean()
plt.figure(figsize=(3*ts.HEIGHT, ts.HEIGHT/2))
ts.plot_series(smooth_df, title=f'Smoothing (win_size={WIN_SIZE})', x_label='Date', y_label='deaths')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# # Aggregation

# %%
def aggregate_by(data: pd.Series, index_var: str, period: str, title: str = '', x_label: str = '', y_label: str = ''):
    index = data.index.to_period(period)
    agg_df = data.copy().groupby(index).mean()
    agg_df[index_var] = index.drop_duplicates().to_timestamp()
    agg_df.set_index(index_var, drop=True, inplace=True)
    ts.plot_series(agg_df, title=title, x_label=x_label, y_label=y_label)

# %% [markdown]
# ## Deaths

# %%
plt.figure(figsize=(3*ts.HEIGHT, ts.HEIGHT))
aggregate_by(data_d, 'Date', 'M', title='Monthly Deaths', x_label='Date', y_label='deaths')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ## Covid

# %%
plt.figure(figsize=(3*ts.HEIGHT, ts.HEIGHT))
aggregate_by(data_c, 'Date', 'W', title='Weekly Aggregate Covid Deaths', x_label='Date', y_label='deaths')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize=(3*ts.HEIGHT, ts.HEIGHT))
aggregate_by(data_c, 'Date', 'M', title='Monthly Aggregate Covid Deaths', x_label='Date', y_label='deaths')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize=(3*ts.HEIGHT, ts.HEIGHT))
aggregate_by(data_c2, 'Date', 'W', title='Weekly Covid Deaths', x_label='Date', y_label='deaths')
plt.xticks(rotation = 45)
plt.show()

# %%
plt.figure(figsize=(3*ts.HEIGHT, ts.HEIGHT))
aggregate_by(data_c2, 'Date', 'M', title='Monthly Covid Deaths', x_label='Date', y_label='deaths')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# # Differentiation
# ## Deaths

# %%
diff_df = data_d.diff()
plt.figure(figsize=(3*ts.HEIGHT, ts.HEIGHT))
ts.plot_series(diff_df, title='Differentiation Deaths PT', x_label='Date', y_label='deaths')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# ## Covid

# %%
diff_df = data_c.diff()
plt.figure(figsize=(3*ts.HEIGHT, ts.HEIGHT))
ts.plot_series(diff_df, title='Differentiation Accumulated Covid', x_label='Date', y_label='deaths')
plt.xticks(rotation = 45)
plt.show()

# %%
diff_df = data_c2.diff()
plt.figure(figsize=(3*ts.HEIGHT, ts.HEIGHT))
ts.plot_series(diff_df, title='Differentiation Covid', x_label='Date', y_label='deaths')
plt.xticks(rotation = 45)
plt.show()
